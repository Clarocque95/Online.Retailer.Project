# %%
                                                # PROBLEM 1 #
# PART 1
# Find the total number of unique products.

# %%
# First, I used the COUNT function to get the total number of values in the product_id column. 
# I then used the COUNT function combined with the DISTINCT statement to find unique product names from the info table. 
# We see that many products have more than one product_id.

# %%
# %%sql
# SELECT COUNT(product_id) as product_id_count, COUNT(DISTINCT product_name) AS unique_products_count
# FROM info
# Out:
#  * postgresql://postgres:***@localhost:5432/Sports.Retailer.Project
# 1 rows affected.
# [(3179, 1511)]

# %%
# PART 2 
# Are there any null values in the info table?

# %%
# I used a COUNT function for every column of the info table and subtracted it from the total count of rows.
# Since the COUNT function does NOT count null values, once we subtract it from count of total rows, we will obtain the number of null values.
# It's no surprise that the product_id column had no NULL values since this is the PRIMARY KEY. The other columns in the info table have NULL values.

# %%
# %%sql
# SELECT COUNT(*) - COUNT(product_id) AS product_id_null_count,
#        COUNT(*) - COUNT(product_name) AS product_name_null_count,
#        COUNT(*) - COUNT(description) AS description_null_count
# FROM info
# Out:
#  * postgresql://postgres:***@localhost:5432/Sports.Retailer.Project
# 1 rows affected.
# [(0, 59, 62)]

# %%
                                                # PROBLEM 2 #
# Which product(s) was most recently viewed and which product(s) was least recently viewed?

# %%
# I joined the traffic and brands tables. There are two select statements (2 tables) which I combined using the UNION operator.
# In the first table, we obtain the least recently viewed products and in the second table we obtain the most recently viewed products.
# This is done by adding a subquery in the WHERE clause. In this subquery we get the MIN and MAX of last_visited date.

# %%
# %%sql
# SELECT brand, t.product_id, last_visited
# FROM traffic t
# JOIN brands b
# ON t.product_id = b.product_id
# WHERE last_visited = (SELECT MIN(last_visited) FROM traffic)
#
# UNION
#
# SELECT brand, t.product_id, last_visited
# FROM traffic t
# JOIN brands b
# ON t.product_id = b.product_id
# WHERE last_visited = (SELECT MAX(last_visited) FROM traffic)
# ORDER BY last_visited
# Out:
#  * postgresql://postgres:***@localhost:5432/Sports.Retailer.Project
# 8 rows affected.
# [('Adidas', 'FV3671', datetime.date(2018, 1, 1)),
#  ('Adidas', 'F34038', datetime.date(2018, 1, 1)),
#  ('Adidas', 'G28372', datetime.date(2018, 1, 1)),
#  ('Adidas', 'F36236', datetime.date(2020, 4, 12)),
#  ('Adidas', 'CJ8116', datetime.date(2020, 4, 12)),
#  ('Adidas', 'CL4156', datetime.date(2020, 4, 12)),
#  ('Nike', 'CI3869-500', datetime.date(2020, 4, 12)),
#  ('Nike', 'CD0917-300', datetime.date(2020, 4, 12))]

# %%
                                                # PROBLEM 3 #
# Find the number of products and the average rating for each brand.

# %%
# We must join the brands and reviews tables and use the COUNT, SUM and ROUND functions.
# I filtered out NULL values for the brand and used a GROUP BY statement for brand.
# The table shows that there is approximately five times more Adidas products than Nike products and that Nike products have a higher rating.

# %%
# %%sql
# SELECT brand,
#        COUNT(*) AS count_products,
# 	   ROUND(AVG(rating), 2) AS average_rating
# FROM brands b
# JOIN info i
# ON b.product_id = i.product_id
# JOIN reviews r
# ON b.product_id = r.product_id
# WHERE brand IS NOT NULL
# GROUP BY brand
# Out:
#  * postgresql://postgres:***@localhost:5432/Sports.Retailer.Project
# 2 rows affected.
# [('Adidas', 2575, Decimal('3.37')), ('Nike', 545, Decimal('4.24'))]

# %%
                                                # PROBLEM 4 #
# PART 1
# For each brand, find the following information: number of products sold, sum of total sales and the minimum, maximum and average of the sale price.

# %%
# We must use MIN, MAX, ROUND, AVG and SUM functions to solve this problem. 
# I joined the transactions and brands tables and used a GROUP BY statement.
# The final table shows that Adidas has sold more products than Nike and collected more revenue. Also, we see that Nike has nearly double the average sale price of Adidas.

# %%
# %%sql
# SELECT brand,
#        COUNT(*) AS number_of_products_sold,
# 	   SUM(sale_price) AS sum_revenue,
#        MIN(sale_price) AS min_sale_price,
# 	   MAX(sale_price) AS max_sale_price,
#        ROUND(AVG(sale_price), 2) AS avg_sale_price
# FROM transactions t
# JOIN brands b
# ON t.product_id = b.product_id
# WHERE brand IS NOT NULL
# GROUP BY brand
# Out:
#  * postgresql://postgres:***@localhost:5432/Sports.Retailer.Project
# 2 rows affected.
# [('Adidas', 17515, Decimal('894696.07'), Decimal('4.49'), Decimal('299.99'), Decimal('51.08')),
#  ('Nike', 3210, Decimal('326572.44'), Decimal('15.95'), Decimal('249.95'), Decimal('101.74'))]

# %%
# PART 2
# What percentage of revenue does each brand have compared to the total revenue?

# %%
# I first need the revenue of a particular brand. Then, I use this result in a subquery and divide it by the total revenue. 
# I used the ROUND function to get 2 decimals, I multiplied by 100 to get a percentage and used the CONCAT function to add a percentage sign. 
# The data shows that Adidas products have made nearly 75% of the total revenue.

# %%
# %%sql
# SELECT
# 	CONCAT(ROUND((SELECT SUM(sale_price)
# 	 			  FROM transactions t
# 	 		      JOIN brands b
# 	              ON t.product_id = b.product_id
# 	              WHERE brand = 'Adidas')
# 	/SUM(sale_price)*100, 2), '%') AS adidas_portion_revenue,
#
# 	CONCAT(ROUND((SELECT SUM(sale_price)
# 	 			  FROM transactions t
# 	 		      JOIN brands b
# 	              ON t.product_id = b.product_id
# 	              WHERE brand = 'Nike')
# 	/SUM(sale_price)*100, 2), '%') AS nike_portion_revenue
# FROM transactions
# Out:
#  * postgresql://postgres:***@localhost:5432/Sports.Retailer.Project
# 1 rows affected.
# [('73.26%', '26.74%')]

# %%
                                               # PROBLEM 5 #
# PART 1
# What are the 10 products with the highest revenue?

# %%
# I joined the transactions, info and brands tables together.
# I used an ORDER BY clause to sort the revenue in descending order and I used a LIMIT clause to only obtain the top 10 rows (top 10 products).
# We see that 9/10 products with the highest revenue are from Adidas.

# %%
# %%sql
# SELECT brand, product_name, SUM(sale_price) AS total_sales
# FROM transactions t
# JOIN info i
# ON t.product_id = i.product_id
# JOIN brands b
# ON t.product_id = b.product_id
# WHERE product_name IS NOT NULL
# GROUP BY product_name, brand
# ORDER BY total_sales DESC
# LIMIT 10
# Out:
#  * postgresql://postgres:***@localhost:5432/Sports.Retailer.Project
# 10 rows affected.
# [('Adidas', "Men's adidas Originals ZX 4000 4D Shoes", Decimal('8619.70')),
#  ('Adidas', "Men's adidas Running Ultraboost 19 Shoes", Decimal('8490.31')),
#  ('Adidas', 'Unisex adidas Originals Marathon Tech Shoes', Decimal('7909.04')),
#  ('Adidas', "Men's adidas Originals Supercourt Shoes", Decimal('7415.15')),
#  ('Nike', 'Nike Air Max 90', Decimal('7402.77')),
#  ('Adidas', "Women's adidas Originals Sambarose Shoes", Decimal('7052.99')),
#  ('Adidas', "Women's adidas Originals NMD_R1 Shoes", Decimal('7043.19')),
#  ('Adidas', "Men's adidas Originals Stan Smith Shoes", Decimal('6317.17')),
#  ('Adidas', "Men's adidas Originals Continental 80 Shoes", Decimal('6216.98')),
#  ('Adidas', "Women's adidas Running Ultraboost 19 Shoes", Decimal('6019.49'))]

# %%
# PART 2
# There is one Nike product in the top 10 of highest selling products. What portion of the revenue does this specific product have in the total revenue for Nike?

# %%
# The query is like PART 1, but we must filter out all Adidas products. 
# I used a subquery within the select statement. This subquery represents the total revenue for Nike products. I divided the revenue for each row by this total revenue.  
# The table shows that the product with the highest revenue represents over 2.25% of the total revenue for Nike products and the next product is at 1.75%.

# %%
# %%sql
# SELECT brand,
#        product_name,
#        SUM(sale_price) as revenue,
# 	   CONCAT(ROUND(SUM(sale_price)/(SELECT SUM(sale_price) as revenue
# 								     FROM transactions t
#                                      JOIN brands b
#                                      ON t.product_id = b.product_id
#                                      WHERE brand = 'Nike')*100, 2), '%') AS portion_of_revenue
# FROM transactions t
# JOIN brands b
# ON t.product_id = b.product_id
# JOIN info i
# ON t.product_id = i.product_id
# WHERE brand = 'Nike'
# GROUP BY product_name, brand
# ORDER BY revenue DESC
# LIMIT 10
# Out:
#  * postgresql://postgres:***@localhost:5432/Sports.Retailer.Project
# 10 rows affected.
# [('Nike', 'Nike Air Max 90', Decimal('7402.77'), '2.27%'),
#  ('Nike', 'Nike Air Max 97', Decimal('5703.31'), '1.75%'),
#  ('Nike', 'Nike Air Max 270 React', Decimal('5204.03'), '1.59%'),
#  ('Nike', 'Nike Air VaporMax 360', Decimal('5128.65'), '1.57%'),
#  ('Nike', 'Nike Air Zoom Pegasus 36', Decimal('4190.07'), '1.28%'),
#  ('Nike', 'Nike Air Max 98', Decimal('3776.88'), '1.16%'),
#  ('Nike', 'Nike Zoom Pegasus Turbo 2', Decimal('3582.91'), '1.10%'),
#  ('Nike', 'Nike Air VaporMax Flyknit 3', Decimal('3568.95'), '1.09%'),
#  ('Nike', 'Nike Air Max 2090', Decimal('3538.60'), '1.08%'),
#  ('Nike', 'Nike Mercurial Vapor 13 Elite FG', Decimal('3519.20'), '1.08%')]

# %%
                                                # PROBLEM 6 #
# PART 1
# Calculate the correlation between sale_price and rating.

# %%
# I used the CORR function to get the correlation coefficient and CAST function to convert the number into a numeric data type.

# %%
# %%sql
# SELECT ROUND(CAST(CORR(sale_price, rating) AS numeric), 2) AS rating_revenue_correlation
# FROM transactions t
# JOIN reviews r
# ON t.product_id = r.product_id
# Out:
#  * postgresql://postgres:***@localhost:5432/Sports.Retailer.Project
# 1 rows affected.
# [(Decimal('0.13'),)]

# %%
# PART 2
# Calculate the correlation between the rating and the number of times a product is sold.

# %%
# Since we can't use an aggregate function within the CORR function, we need a CTE (common table expression).

# %%
# %%sql
# WITH CTE AS
# (
# 	SELECT product_id, COUNT(product_id) as total_sales
#     FROM transactions
#     GROUP BY product_id
# )
# SELECT ROUND(CAST(CORR(total_sales, rating) AS numeric), 2) AS rating_revenue_correlation
# FROM CTE
# JOIN reviews r
# ON cte.product_id = r.product_id
# Out:
#  * postgresql://postgres:***@localhost:5432/Sports.Retailer.Project
# 1 rows affected.
# [(Decimal('0.37'),)]

# %%
                                                # PROBLEM 7 #
# Create a table showing the rating within different categories ranging from terrible to excellent for each brand. 
# Also include the number of products and the total revenue within each category.

# %%
# A CASE statement must be used to achieve the desired result. I also joined the reviews, brands and transactions tables and sorted the results by total revenue in descending order. 
# The final table shows Nike has no products in the terrible rating category and each brand has more products in the excellent and good rating categories.

# %%
# %%sql
# SELECT brand,
# 	CASE
# 		WHEN 0 <= rating AND rating < 1 THEN 'Terrible rating'
# 		WHEN 1 <= rating AND rating < 2 THEN 'Poor rating'
# 		WHEN 2 <= rating AND rating < 3 THEN 'Mediocre rating'
# 		WHEN 3 <= rating AND rating < 4 THEN 'Good rating'
# 		ELSE 'Excellent rating'
# 	END AS rating_category,
# 	COUNT(DISTINCT t.product_id) AS number_of_products,
# 	COUNT(*) AS number_of_products_sold,
# 	SUM(sale_price) AS total_revenue
# FROM reviews r
# JOIN brands b
# ON r.product_id = b.product_id
# JOIN transactions t
# ON r.product_id = t.product_id
# WHERE rating IS NOT NULL
# GROUP BY brand, rating_category
# ORDER BY total_revenue DESC
# Out:
#  * postgresql://postgres:***@localhost:5432/Sports.Retailer.Project
# 9 rows affected.
# [('Adidas', 'Excellent rating', 921, 7192, Decimal('368995.22')),
#  ('Adidas', 'Good rating', 772, 6605, Decimal('345311.46')),
#  ('Nike', 'Excellent rating', 266, 2081, Decimal('214638.51')),
#  ('Adidas', 'Mediocre rating', 609, 2412, Decimal('117449.95')),
#  ('Nike', 'Good rating', 67, 574, Decimal('59059.72')),
#  ('Adidas', 'Poor rating', 159, 1000, Decimal('47260.25')),
#  ('Adidas', 'Terrible rating', 61, 157, Decimal('8111.43')),
#  ('Nike', 'Mediocre rating', 19, 61, Decimal('5714.53')),
#  ('Nike', 'Poor rating', 6, 53, Decimal('4474.11'))]

# %%
                                                # PROBLEM 8 #
# Create different categories for the length of the description column and calculate the number of products and the average rating for each category.

# %%
# This query will return the max character length for the description column. I used the MAX and LENGTH functions.

# %%
# %%sql
# SELECT MAX(LENGTH(description)) AS max_description_length FROM info
# Out:
#  * postgresql://postgres:***@localhost:5432/Sports.Retailer.Project
# 1 rows affected.
# [(687,)]

# %%
# After obtaining the maximum length of the description column, I created different categories using a CASE statement. 
# I used COUNT and AVG functions and I joined info and reviews tables together. 
# The results shows that most products have a description length between 200-299 and that the average rating is similar for each category.

# %%
# %%sql
# SELECT
# 	CASE
# 	WHEN LENGTH(description) < 100 THEN '0-99'
# 	WHEN LENGTH(description) < 200 THEN '100-199'
# 	WHEN LENGTH(description) < 300 THEN '200-299'
# 	WHEN LENGTH(description) < 400 THEN '300-399'
# 	WHEN LENGTH(description) < 500 THEN '400-499'
# 	WHEN LENGTH(description) < 600 THEN '500-599'
# 	ELSE '600-699'
# 	END AS description_length,
#
# 	COUNT(i.product_id) AS number_of_products,
# 	ROUND(AVG(rating), 2) AS average_rating
#
# FROM info i
# JOIN reviews r
# ON i.product_id = r.product_id
# WHERE description IS NOT NULL
# GROUP BY description_length
# ORDER BY description_length
# Out:
#  * postgresql://postgres:***@localhost:5432/Sports.Retailer.Project
# 7 rows affected.
# [('0-99', 6, Decimal('3.73')),
#  ('100-199', 503, Decimal('3.68')),
#  ('200-299', 1804, Decimal('3.44')),
#  ('300-399', 652, Decimal('3.44')),
#  ('400-499', 122, Decimal('3.38')),
#  ('500-599', 15, Decimal('3.34')),
#  ('600-699', 15, Decimal('3.65'))]

# %%
                                                # PROBLEM 9 #
# PART 1
# Find the number of products for men and for women.

# %%
# In the WHERE clause, I used the LIKE operator for the product_name column.
# I used CROSS JOIN to join the result for 'men' and the result for 'women'.
# Finally, it's critical to use the LOWER function in the WHERE clause. The LIKE operator is case sensitive, therefore 'Men' is different than 'men'. 
# The table shows that most products are for men.

# %%
# %%sql
# SELECT COUNT(i1.product_id) AS men_products_count, i2.women_products_count
# FROM info i1
# CROSS JOIN (SELECT COUNT(product_id) AS women_products_count
# 			FROM info
# 			WHERE LOWER(product_name) LIKE '%women%') i2
# WHERE LOWER(product_name) LIKE '%men%'
# GROUP BY i2.women_products_count
# Out:
#  * postgresql://postgres:***@localhost:5432/Sports.Retailer.Project
# 1 rows affected.
# [(2488, 766)]

# %%
# PART 2
# Find the number of products that are either slippers or sandals.

# %%
# To solve this problem, I used the OR operator within the WHERE clause.

# %%
# %%sql
# SELECT COUNT(product_id) AS product_count
# FROM info
# WHERE LOWER(product_name) LIKE '%slipper%' OR LOWER(product_name) LIKE '%sandal%'
# Out:
#  * postgresql://postgres:***@localhost:5432/Sports.Retailer.Project
# 1 rows affected.
# [(145,)]

# %%
# PART 3
# Most of the products sold are shoes, what portion of the total revenue are from shoe sales?

# %%
# We must use the SUM function and join info and transactions tables together.
# This shows that approximately 68% of the total revenue is from shoe sales.

# %%
# %%sql
# SELECT CONCAT(ROUND((SELECT SUM(sale_price) AS revenue_shoes
# 		FROM info i
#         JOIN transactions t
#         ON i.product_id = t.product_id
#         WHERE LOWER(product_name) LIKE '%shoes%') / SUM(sale_price)*100, 2), '%') AS shoe_products_revenue_portion
# FROM transactions
# Out:
#  * postgresql://postgres:***@localhost:5432/Sports.Retailer.Project
# 1 rows affected.
# [('67.74%',)]

# %%
                                                # PROBLEM 10 #
# PART 1
# Find the number of products for each sale price.

# %%
# Join transactions to brands on product_id and use the COUNT function with a DISTINCT statement on the product_id column from the transactions table.
# Aggregate results by brand and sale_price and sort the results by sale_price in descending order.
# We see that Adidas products occupy most of the low sale prices.

# %%
# %%sql
# SELECT brand, sale_price AS sale_price, COUNT(DISTINCT t.product_id) AS count
# FROM transactions t
# JOIN brands b
# ON t.product_id = b.product_id
# WHERE brand IS NOT NULL
# GROUP BY brand, sale_price
# ORDER BY sale_price DESC
# Out:
#  * postgresql://postgres:***@localhost:5432/Sports.Retailer.Project
# 224 rows affected.
# [('Adidas', Decimal('299.99'), 2),
#  ('Adidas', Decimal('279.99'), 3),
#  ('Nike', Decimal('249.95'), 2),
#  ('Adidas', Decimal('239.99'), 4),
#  ('Adidas', Decimal('229.99'), 1),
#  ('Nike', Decimal('229.95'), 4),
#  ('Adidas', Decimal('219.99'), 4),
#  ('Nike', Decimal('219.95'), 2),
#  ('Nike', Decimal('209.95'), 1),
#  ('Adidas', Decimal('199.99'), 6),
#  ('Nike', Decimal('199.95'), 3),
#  ('Adidas', Decimal('189.99'), 2),
#  ('Nike', Decimal('189.95'), 6),
#  ('Adidas', Decimal('179.99'), 18),
#  ('Nike', Decimal('179.95'), 1),
#  ('Adidas', Decimal('169.99'), 9),
#  ('Nike', Decimal('169.95'), 16),
#  ('Adidas', Decimal('159.99'), 3),
#  ('Nike', Decimal('159.97'), 1),
#  ('Nike', Decimal('159.95'), 30),
#  ('Nike', Decimal('151.97'), 1),
#  ('Adidas', Decimal('149.99'), 11),
#  ('Nike', Decimal('149.95'), 17),
#  ('Nike', Decimal('144.95'), 1),
#  ('Nike', Decimal('143.97'), 2),
#  ('Adidas', Decimal('139.99'), 9),
#  ('Nike', Decimal('139.95'), 17),
#  ('Adidas', Decimal('137.99'), 5),
#  ('Nike', Decimal('135.97'), 8),
#  ('Nike', Decimal('134.95'), 1),
#  ('Adidas', Decimal('132.99'), 1),
#  ('Nike', Decimal('132.97'), 1),
#  ('Adidas', Decimal('131.99'), 2),
#  ('Adidas', Decimal('129.99'), 30),
#  ('Nike', Decimal('129.95'), 14),
#  ('Nike', Decimal('127.97'), 9),
#  ('Adidas', Decimal('125.99'), 9),
#  ('Nike', Decimal('125.97'), 2),
#  ('Adidas', Decimal('119.99'), 23),
#  ('Nike', Decimal('119.97'), 3),
#  ('Nike', Decimal('119.95'), 26),
#  ('Adidas', Decimal('118.99'), 12),
#  ('Nike', Decimal('118.97'), 2),
#  ('Adidas', Decimal('114.99'), 2),
#  ('Adidas', Decimal('111.99'), 6),
#  ('Nike', Decimal('111.97'), 18),
#  ('Adidas', Decimal('109.99'), 48),
#  ('Nike', Decimal('109.95'), 28),
#  ('Adidas', Decimal('107.99'), 1),
#  ('Adidas', Decimal('104.99'), 3),
#  ('Nike', Decimal('104.97'), 2),
#  ('Nike', Decimal('104.95'), 2),
#  ('Nike', Decimal('103.97'), 4),
#  ('Adidas', Decimal('101.99'), 1),
#  ('Nike', Decimal('101.97'), 3),
#  ('Adidas', Decimal('99.99'), 19),
#  ('Nike', Decimal('99.95'), 40),
#  ('Adidas', Decimal('97.99'), 2),
#  ('Nike', Decimal('97.97'), 3),
#  ('Nike', Decimal('96.37'), 1),
#  ('Adidas', Decimal('95.99'), 6),
#  ('Nike', Decimal('95.97'), 12),
#  ('Adidas', Decimal('94.99'), 3),
#  ('Nike', Decimal('94.95'), 1),
#  ('Adidas', Decimal('90.99'), 1),
#  ('Nike', Decimal('90.97'), 3),
#  ('Adidas', Decimal('89.99'), 41),
#  ('Nike', Decimal('89.97'), 2),
#  ('Nike', Decimal('89.95'), 19),
#  ('Nike', Decimal('87.97'), 4),
#  ('Nike', Decimal('87.95'), 2),
#  ('Adidas', Decimal('85.99'), 2),
#  ('Adidas', Decimal('84.99'), 4),
#  ('Nike', Decimal('84.95'), 4),
#  ('Adidas', Decimal('83.99'), 9),
#  ('Nike', Decimal('83.97'), 8),
#  ('Adidas', Decimal('79.99'), 97),
#  ('Nike', Decimal('79.97'), 5),
#  ('Nike', Decimal('79.95'), 31),
#  ('Adidas', Decimal('77.99'), 39),
#  ('Nike', Decimal('77.97'), 5),
#  ('Adidas', Decimal('76.99'), 2),
#  ('Nike', Decimal('76.97'), 7),
#  ('Adidas', Decimal('76'), 1),
#  ('Adidas', Decimal('75.99'), 43),
#  ('Nike', Decimal('75.97'), 1),
#  ('Nike', Decimal('75.95'), 3),
#  ('Adidas', Decimal('74.99'), 14),
#  ('Nike', Decimal('74.95'), 9),
#  ('Nike', Decimal('72.95'), 1),
#  ('Adidas', Decimal('71.99'), 50),
#  ('Nike', Decimal('71.97'), 11),
#  ('Adidas', Decimal('69.99'), 30),
#  ('Nike', Decimal('69.97'), 4),
#  ('Nike', Decimal('69.95'), 14),
#  ('Adidas', Decimal('68'), 1),
#  ('Nike', Decimal('67.97'), 2),
#  ('Adidas', Decimal('65.99'), 47),
#  ('Nike', Decimal('65.97'), 5),
#  ('Nike', Decimal('65.95'), 1),
#  ('Adidas', Decimal('64.99'), 23),
#  ('Nike', Decimal('64.95'), 9),
#  ('Adidas', Decimal('64'), 1),
#  ('Nike', Decimal('63.97'), 7),
#  ('Nike', Decimal('63.17'), 1),
#  ('Adidas', Decimal('62.99'), 1),
#  ('Nike', Decimal('62.97'), 2),
#  ('Adidas', Decimal('60'), 1),
#  ('Adidas', Decimal('59.99'), 95),
#  ('Nike', Decimal('59.97'), 6),
#  ('Nike', Decimal('59.95'), 9),
#  ('Nike', Decimal('59.47'), 3),
#  ('Adidas', Decimal('57.59'), 1),
#  ('Adidas', Decimal('56'), 4),
#  ('Adidas', Decimal('55.99'), 39),
#  ('Nike', Decimal('55.97'), 7),
#  ('Adidas', Decimal('54.99'), 16),
#  ('Nike', Decimal('54.95'), 6),
#  ('Adidas', Decimal('53.99'), 28),
#  ('Nike', Decimal('53.97'), 4),
#  ('Adidas', Decimal('53.19'), 7),
#  ('Adidas', Decimal('52.99'), 5),
#  ('Nike', Decimal('52.95'), 1),
#  ('Nike', Decimal('52.47'), 6),
#  ('Adidas', Decimal('52'), 3),
#  ('Adidas', Decimal('51.59'), 1),
#  ('Adidas', Decimal('49.99'), 69),
#  ('Nike', Decimal('49.95'), 3),
#  ('Nike', Decimal('48.97'), 1),
#  ('Adidas', Decimal('48'), 2),
#  ('Adidas', Decimal('47.99'), 97),
#  ('Nike', Decimal('47.97'), 5),
#  ('Adidas', Decimal('46.19'), 2),
#  ('Adidas', Decimal('45.99'), 29),
#  ('Adidas', Decimal('45.59'), 61),
#  ('Nike', Decimal('45.47'), 1),
#  ('Adidas', Decimal('44.99'), 33),
#  ('Nike', Decimal('44.97'), 1),
#  ('Nike', Decimal('44.95'), 6),
#  ('Adidas', Decimal('44.79'), 3),
#  ('Adidas', Decimal('44'), 6),
#  ('Adidas', Decimal('42.99'), 7),
#  ('Adidas', Decimal('42.39'), 1),
#  ('Adidas', Decimal('41.99'), 36),
#  ('Nike', Decimal('41.97'), 1),
#  ('Adidas', Decimal('40'), 7),
#  ('Adidas', Decimal('39.99'), 155),
#  ('Nike', Decimal('39.97'), 2),
#  ('Nike', Decimal('39.95'), 1),
#  ('Adidas', Decimal('39.59'), 52),
#  ('Adidas', Decimal('39.19'), 5),
#  ('Adidas', Decimal('38.39'), 9),
#  ('Adidas', Decimal('37.99'), 40),
#  ('Nike', Decimal('36.95'), 1),
#  ('Adidas', Decimal('36.79'), 8),
#  ('Adidas', Decimal('36'), 3),
#  ('Adidas', Decimal('35.99'), 68),
#  ('Nike', Decimal('35.97'), 1),
#  ('Adidas', Decimal('34.99'), 46),
#  ('Nike', Decimal('34.97'), 3),
#  ('Adidas', Decimal('34.39'), 4),
#  ('Adidas', Decimal('34'), 1),
#  ('Adidas', Decimal('33.59'), 44),
#  ('Nike', Decimal('33.57'), 1),
#  ('Adidas', Decimal('32.99'), 30),
#  ('Adidas', Decimal('32.19'), 1),
#  ('Adidas', Decimal('32'), 3),
#  ('Adidas', Decimal('31.99'), 8),
#  ('Nike', Decimal('31.97'), 1),
#  ('Adidas', Decimal('31.79'), 6),
#  ('Adidas', Decimal('31.49'), 1),
#  ('Nike', Decimal('31.47'), 2),
#  ('Adidas', Decimal('30.4'), 1),
#  ('Adidas', Decimal('30'), 1),
#  ('Adidas', Decimal('29.99'), 140),
#  ('Nike', Decimal('29.95'), 1),
#  ('Adidas', Decimal('28.79'), 8),
#  ('Adidas', Decimal('27.99'), 102),
#  ('Nike', Decimal('27.95'), 1),
#  ('Adidas', Decimal('27.59'), 34),
#  ('Adidas', Decimal('27.49'), 2),
#  ('Adidas', Decimal('26.99'), 3),
#  ('Adidas', Decimal('26.49'), 30),
#  ('Adidas', Decimal('26.4'), 1),
#  ('Adidas', Decimal('25.79'), 5),
#  ('Adidas', Decimal('24.99'), 101),
#  ('Nike', Decimal('24.95'), 3),
#  ('Adidas', Decimal('24'), 5),
#  ('Adidas', Decimal('23.99'), 49),
#  ('Nike', Decimal('23.97'), 1),
#  ('Adidas', Decimal('22.99'), 86),
#  ('Adidas', Decimal('22.79'), 6),
#  ('Adidas', Decimal('22.49'), 1),
#  ('Adidas', Decimal('22.4'), 3),
#  ('Adidas', Decimal('21.59'), 13),
#  ('Adidas', Decimal('21.49'), 39),
#  ('Adidas', Decimal('20'), 6),
#  ('Adidas', Decimal('19.99'), 26),
#  ('Nike', Decimal('19.95'), 2),
#  ('Adidas', Decimal('19.79'), 11),
#  ('Adidas', Decimal('19.2'), 2),
#  ('Adidas', Decimal('18.99'), 13),
#  ('Adidas', Decimal('18.89'), 11),
#  ('Adidas', Decimal('18.4'), 5),
#  ('Adidas', Decimal('17.99'), 20),
#  ('Adidas', Decimal('17.49'), 8),
#  ('Adidas', Decimal('16.79'), 19),
#  ('Adidas', Decimal('16.49'), 6),
#  ('Nike', Decimal('15.95'), 3),
#  ('Adidas', Decimal('14.99'), 19),
#  ('Adidas', Decimal('13.99'), 6),
#  ('Adidas', Decimal('13.49'), 1),
#  ('Adidas', Decimal('12.99'), 8),
#  ('Adidas', Decimal('12.49'), 6),
#  ('Adidas', Decimal('9.99'), 5),
#  ('Adidas', Decimal('9.59'), 4),
#  ('Adidas', Decimal('8.99'), 14),
#  ('Adidas', Decimal('7.79'), 16),
#  ('Adidas', Decimal('7.49'), 6),
#  ('Adidas', Decimal('6.49'), 3),
#  ('Adidas', Decimal('6'), 1),
#  ('Adidas', Decimal('5.99'), 8),
#  ('Adidas', Decimal('4.99'), 4),
#  ('Adidas', Decimal('4.49'), 1)]

# %%
# PART 2
# Find the most popular sale price for each brand.

# %%
# Most popular means the sale price with the most products sold, not the sale price with the highest number of products. 
# I can use a query nearly identical to PART 1 within a CTE, but I need to use COUNT(*) instead of COUNT(DISTINCT t.product_id).
# In there WHERE clause, I added a subquery that returns the max count for a specific brand. 
# Also, I used the UNION operator to join the result for Adidas with the result for Nike.

# %%
# %%sql
# WITH CTE AS
# (
# 	SELECT brand, sale_price AS sale_price, COUNT(*) AS count
# 	FROM transactions t
# 	JOIN brands b
# 	ON t.product_id = b.product_id
# 	WHERE brand IS NOT NULL
# 	GROUP BY brand, sale_price
# 	ORDER BY sale_price DESC
# )
# SELECT *
# FROM CTE
# WHERE count = (SELECT MAX(count) FROM CTE WHERE brand = 'Adidas') AND brand = 'Adidas'
# GROUP BY brand, sale_price, count
# UNION
# SELECT *
# FROM CTE
# WHERE count = (SELECT MAX(count) FROM CTE WHERE brand = 'Nike') AND brand = 'Nike'
# GROUP BY brand, sale_price, count
# Out:
#  * postgresql://postgres:***@localhost:5432/Sports.Retailer.Project
# 2 rows affected.
# [('Adidas', Decimal('39.99'), 1081), ('Nike', Decimal('99.95'), 240)]

# %%
                                                # PROBLEM 11 #
# PART 1 
# Which months have a total revenue over 45,000$?

# %%
# The DATE_PART function is used in this query to get the month and the year from the date column in the transactions table.
# The function SUM was used to calculate the total revenue for every month.
# I added a HAVING clause since it's impossible to use aggregate functions in a WHERE CLAUSE. This clause will filter out all the months with less than 45,000$ in total revenue. 
# I used a GROUP BY statement for month and year columns. I also sorted the table by year and month respectively.

# %%
# %%sql
# SELECT DATE_PART('month', date) AS month,
#        DATE_PART('year', date) AS year,
# 	   SUM(sale_price) AS total_revenue
# FROM transactions
# GROUP BY month, year
# HAVING SUM(sale_price) > 45000
# ORDER BY 2, 3
# Out:
#  * postgresql://postgres:***@localhost:5432/Sports.Retailer.Project
# 13 rows affected.
# [(1.0, 2018.0, Decimal('45161.71')),
#  (6.0, 2018.0, Decimal('46193.66')),
#  (7.0, 2018.0, Decimal('47111.89')),
#  (10.0, 2019.0, Decimal('45403.93')),
#  (7.0, 2019.0, Decimal('46012.82')),
#  (12.0, 2019.0, Decimal('46716.27')),
#  (8.0, 2019.0, Decimal('46840.04')),
#  (11.0, 2019.0, Decimal('46859.83')),
#  (3.0, 2019.0, Decimal('47287.03')),
#  (5.0, 2019.0, Decimal('47538.22')),
#  (1.0, 2019.0, Decimal('47585.67')),
#  (1.0, 2020.0, Decimal('46985.65')),
#  (2.0, 2020.0, Decimal('47526.71'))]

# %%
# PART 2 
# Find the month and year with the highest revenue.

# %%
# I used a CTE which is like the query in part 1, but without the HAVING clause. 
# I added a subquery in the WHERE clause to select the maximum total revenue.
# The month of January in 2019 was the month with the highest total revenue.

# %%
# %%sql
# WITH CTE AS
# (
# 	SELECT DATE_PART('month', date) AS month, DATE_PART('year', date) AS year, SUM(sale_price) AS total_revenue
# 	FROM transactions
#     GROUP BY month, year
#     ORDER BY 2, 1
# )
# SELECT *
# FROM CTE
# WHERE total_revenue = (SELECT MAX(total_revenue) FROM CTE)
# Out:
#  * postgresql://postgres:***@localhost:5432/Sports.Retailer.Project
# 1 rows affected.
# [(1.0, 2019.0, Decimal('47585.67'))]

# %%
# PART 3
# Find the monthly average revenue for each year.

# %%
# The solve this problem, we can't simple use the AVG function. This will lead to an incorrect result.
# To find the average revenue per month for each year, we must divide the total yearly revenue by the number of months within that year.
# The get the number of months within each year, I used a COUNT function and added a DISTINCT statement. Without the DISTINCT statement, the result would be incorrect.

# %%
# %%sql
# SELECT DATE_PART('year', date) AS year,
#        SUM(sale_price) AS total_revenue,
# 	   ROUND(SUM(sale_price)/COUNT(DISTINCT DATE_PART('month', date)), 2) AS monthly_average
# FROM transactions
# GROUP BY year
# ORDER BY year
# Out:
#  * postgresql://postgres:***@localhost:5432/Sports.Retailer.Project
# 3 rows affected.
# [(2018.0, Decimal('524862.06'), Decimal('43738.51')),
#  (2019.0, Decimal('542297.05'), Decimal('45191.42')),
#  (2020.0, Decimal('154109.40'), Decimal('38527.35'))]

# %%
# The previous table showed that the average revenue for 2020 is low compared to 2018 and 2019. 
# This is because we divided the total revenue of 2020 by 4 (number of months), but the fourth month is not complete, therefore the query must be modified.
# In this query, I filtered out data from the month of April and only kept the data from January to March (3 months in total).
# We now see that the monthly average revenue for 2020 is higher than 2018 and 2019!

# %%
# %%sql
# SELECT DATE_PART('year', date) AS year, SUM(sale_price) AS total_revenue, ROUND(SUM(sale_price)/COUNT(DISTINCT DATE_PART('month', date)), 2) AS monthly_average
# FROM transactions
# WHERE DATE_PART('year', date) = '2020' AND DATE_PART('month', date) <= 3
# GROUP BY year
# ORDER BY year
# Out:
#  * postgresql://postgres:***@localhost:5432/Sports.Retailer.Project
# 1 rows affected.
# [(2020.0, Decimal('139288.98'), Decimal('46429.66'))]

# %%
# PART 4
# Find the total revenue and the average revenue by brand for each year.

# %%
# Very similar to part 3, but we must also join the brands table and GROUP BY brand. 
# Also, this time I used a UNION operator so that we can see all the data in one table.  
# We see that Nike's monthly average in 2020 is very high compared to other years (but 2020 is not yet over), whereas Adidas's monthly average is similar for every year.

# %%
# %%sql
# SELECT brand,
#        DATE_PART('year', date) AS year,
#        SUM(sale_price) AS total_revenue,
# 	   ROUND(SUM(sale_price)/COUNT(DISTINCT DATE_PART('month', date)), 2) AS monthly_average
# FROM transactions t
# JOIN brands b
# ON t.product_id = b.product_id
# WHERE DATE_PART('year', date) <> '2020'
# GROUP BY brand, year
#
# UNION
#
# SELECT brand,
#        DATE_PART('year', date) AS year,
#        SUM(sale_price) AS total_revenue,
# 	   ROUND(SUM(sale_price)/COUNT(DISTINCT DATE_PART('month', date)), 2) AS monthly_average
# FROM transactions t
# JOIN brands b
# ON t.product_id = b.product_id
# WHERE DATE_PART('year', date) = '2020' AND DATE_PART('month', date) <= 3
# GROUP BY brand, year
# ORDER BY brand, year
# Out:
#  * postgresql://postgres:***@localhost:5432/Sports.Retailer.Project
# 6 rows affected.
# [('Adidas', 2018.0, Decimal('384846.67'), Decimal('32070.56')),
#  ('Adidas', 2019.0, Decimal('399664.90'), Decimal('33305.41')),
#  ('Adidas', 2020.0, Decimal('99937.35'), Decimal('33312.45')),
#  ('Nike', 2018.0, Decimal('140015.39'), Decimal('11667.95')),
#  ('Nike', 2019.0, Decimal('142632.15'), Decimal('11886.01')),
#  ('Nike', 2020.0, Decimal('39351.63'), Decimal('13117.21'))]

# %%
                                                # PROBLEM 12 #
# PART 1
# List the total sales by month for all years combined.

# %%
# I used a case statement to replace the months from numbers to the actual name of the month. This makes it easier to read and see quickly which months have the highest sales. 
# I excluded sales from 2020, since the data stops during the month of April. If I had kept this data, it would have skewed the results for the months of Jan, Feb and March.
# The data is aggregated by month and the total revenue is sorted in descending order.
# We see that July has the highest total sales and that February has the lowest total sales.

# %%
# %%sql
# SELECT CASE
#        WHEN DATE_PART('month', date) = 1 THEN 'January'
#        WHEN DATE_PART('month', date) = 2 THEN 'February'
# 	   WHEN DATE_PART('month', date) = 3 THEN 'March'
# 	   WHEN DATE_PART('month', date) = 4 THEN 'April'
# 	   WHEN DATE_PART('month', date) = 5 THEN 'May'
# 	   WHEN DATE_PART('month', date) = 6 THEN 'June'
# 	   WHEN DATE_PART('month', date) = 7 THEN 'July'
#        WHEN DATE_PART('month', date) = 8 THEN 'August'
# 	   WHEN DATE_PART('month', date) = 9 THEN 'September'
# 	   WHEN DATE_PART('month', date) = 10 THEN 'October'
# 	   WHEN DATE_PART('month', date) = 11 THEN 'November'
# 	   ELSE 'December'
# 	   END AS month,
#
# 	   SUM(sale_price) AS total_revenue
#
# FROM transactions t
# WHERE DATE_PART('year', date) <> '2020'
# GROUP BY month
# ORDER BY 2 DESC
# Out:
#  * postgresql://postgres:***@localhost:5432/Sports.Retailer.Project
# 12 rows affected.
# [('July', Decimal('93124.71')),
#  ('January', Decimal('92747.38')),
#  ('August', Decimal('91781.29')),
#  ('May', Decimal('91086.75')),
#  ('March', Decimal('90541.64')),
#  ('October', Decimal('89950.95')),
#  ('November', Decimal('89460.66')),
#  ('June', Decimal('89435.83')),
#  ('December', Decimal('89434.84')),
#  ('April', Decimal('86580.85')),
#  ('September', Decimal('84190.34')),
#  ('February', Decimal('78823.87'))]

# %%
# PART 2
# List the total sales by season for each brand.

# %%
# I used a CASE statement to group the months in different categories (seasons).
# I joined the brands and transactions tables and excluded data from 2020 for the same reason as in part 1.
# Finally the data is aggregated by season and brand and I sorted total revenue in descending order.

# %%
# %%sql
# SELECT CASE
#        WHEN DATE_PART('month', date) IN (1,2,12)  THEN 'Winter'
# 	   WHEN DATE_PART('month', date) IN (3,4,5)  THEN 'Spring'
# 	   WHEN DATE_PART('month', date) IN (6,7,8)  THEN 'Summer'
# 	   WHEN DATE_PART('month', date) IN (9,10,11)  THEN 'Fall'
#        END AS season,
# 	   brand, SUM(sale_price) AS total_revenue
# FROM brands b
# JOIN transactions t
# ON b.product_id = t.product_id
# WHERE brand IS NOT NULL AND DATE_PART('year', date) <> '2020'
# GROUP BY season, brand
# ORDER by total_revenue DESC
# Out:
#  * postgresql://postgres:***@localhost:5432/Sports.Retailer.Project
# 8 rows affected.
# [('Summer', 'Adidas', Decimal('199313.53')),
#  ('Spring', 'Adidas', Decimal('196516.91')),
#  ('Winter', 'Adidas', Decimal('194508.93')),
#  ('Fall', 'Adidas', Decimal('194172.20')),
#  ('Summer', 'Nike', Decimal('75028.30')),
#  ('Spring', 'Nike', Decimal('71692.33')),
#  ('Fall', 'Nike', Decimal('69429.75')),
#  ('Winter', 'Nike', Decimal('66497.16'))]

# %%
                                                # PROBLEM 13 #
# PART 1
# Create a table showing the difference in total revenue per month for the year 2019. Also include a column with the difference in a percentage format.

# %%
# I used the DATE_PART function to get the months and the years from the date column of the transactions table.
# We need the window function LAG() to solve this problem.
# We see that from January to February the company had the biggest decrease in total revenue and from February to March, the company saw the highest increase in total sales.
# The table also shows that the total revenue varies more within the first 5 months of the year.

# %%
# %%sql
# SELECT DATE_PART('year', date) AS year,
# 	   DATE_PART('month', date) AS month,
# 	   SUM(sale_price) AS total_monthly_revenue,
# 	   SUM(sale_price) - LAG(SUM(sale_price)) OVER() AS total_monthly_revenue_diff,
# 	   CONCAT(ROUND((SUM(sale_price) - LAG(SUM(sale_price)) OVER()) / SUM(sale_price)*100, 2), '%') AS total_monthly_revenue_diff_percentage
# FROM transactions
# WHERE DATE_PART('year', date) = 2019
# GROUP BY month, year
# ORDER BY 1, 2
# Out:
#  * postgresql://postgres:***@localhost:5432/Sports.Retailer.Project
# 12 rows affected.
# [(2019.0, 1.0, Decimal('47585.67'), None, '%'),
#  (2019.0, 2.0, Decimal('39963.17'), Decimal('-7622.50'), '-19.07%'),
#  (2019.0, 3.0, Decimal('47287.03'), Decimal('7323.86'), '15.49%'),
#  (2019.0, 4.0, Decimal('42146.71'), Decimal('-5140.32'), '-12.20%'),
#  (2019.0, 5.0, Decimal('47538.22'), Decimal('5391.51'), '11.34%'),
#  (2019.0, 6.0, Decimal('43242.17'), Decimal('-4296.05'), '-9.93%'),
#  (2019.0, 7.0, Decimal('46012.82'), Decimal('2770.65'), '6.02%'),
#  (2019.0, 8.0, Decimal('46840.04'), Decimal('827.22'), '1.77%'),
#  (2019.0, 9.0, Decimal('42701.19'), Decimal('-4138.85'), '-9.69%'),
#  (2019.0, 10.0, Decimal('45403.93'), Decimal('2702.74'), '5.95%'),
#  (2019.0, 11.0, Decimal('46859.83'), Decimal('1455.90'), '3.11%'),
#  (2019.0, 12.0, Decimal('46716.27'), Decimal('-143.56'), '-0.31%')]

# %%
# PART 2
# Create a table showing the difference in average daily revenue per month for the year 2018 and Nike products only. Also include a column with the difference in a percentage format.

# %%
# The query is like part 1, but it's more complicated since we can't combine AVG and SUM functions together (Can't use AVG(SUM(sale_price))).
# I used a similar logic to problem 11 part 3, where I used a COUNT function with a distinct statement. So, I divide the monthly revenue by the number of days within that month.
# Finally, I filtered the data for the year 2018 and for Nike products.  
# The table shows a considerable decrease in daily average revenue in the month of March.

# %%
# %%sql
# SELECT DATE_PART('year', date) AS year,
#        DATE_PART('month', date) AS month,
# 	   ROUND(SUM(sale_price)/COUNT(DISTINCT date), 2) AS avg_daily_revenue,
# 	   ROUND((SUM(sale_price)/COUNT(DISTINCT date)) - (LAG(SUM(sale_price)/COUNT(DISTINCT date)) OVER ()), 2) AS avg_daily_revenue_diff,
# 	   CONCAT(ROUND(((SUM(sale_price)/COUNT(DISTINCT date)) - (LAG(SUM(sale_price)/COUNT(DISTINCT date)) OVER ())) / (SUM(sale_price)/COUNT(DISTINCT date))*100, 2), '%') AS avg_daily_revenue_diff_percentage
# FROM transactions t
# JOIN brands b
# ON t.product_id = b.product_id
# WHERE brand = 'Nike' AND DATE_PART('year', date) = '2018'
# GROUP BY month, year
# ORDER BY month
# Out:
#  * postgresql://postgres:***@localhost:5432/Sports.Retailer.Project
# 12 rows affected.
# [(2018.0, 1.0, Decimal('390.42'), None, '%'),
#  (2018.0, 2.0, Decimal('359.15'), Decimal('-31.27'), '-8.71%'),
#  (2018.0, 3.0, Decimal('423.76'), Decimal('64.61'), '15.25%'),
#  (2018.0, 4.0, Decimal('460.39'), Decimal('36.63'), '7.96%'),
#  (2018.0, 5.0, Decimal('336.48'), Decimal('-123.92'), '-36.83%'),
#  (2018.0, 6.0, Decimal('452.26'), Decimal('115.79'), '25.60%'),
#  (2018.0, 7.0, Decimal('423.72'), Decimal('-28.54'), '-6.74%'),
#  (2018.0, 8.0, Decimal('367.49'), Decimal('-56.23'), '-15.30%'),
#  (2018.0, 9.0, Decimal('334.98'), Decimal('-32.52'), '-9.71%'),
#  (2018.0, 10.0, Decimal('361.97'), Decimal('27.00'), '7.46%'),
#  (2018.0, 11.0, Decimal('397.76'), Decimal('35.79'), '9.00%'),
#  (2018.0, 12.0, Decimal('377.61'), Decimal('-20.14'), '-5.33%')]

# %%
                                                # PROBLEM 14 #
# PART 1
# Create a table showing the monthly revenue and the running total for the year 2019 and for Addidas products only.

# %%
# I first wrote a query returning a table showing the monthly revenue for the year 2019.
# I used a window function that calculates the yearly revenue running total for 2019.

# %%
# %%sql
# WITH CTE AS
# (
#     SELECT DATE_PART('year', date) AS year, DATE_PART('month', date) AS month, SUM(sale_price) as monthly_revenue
#     FROM transactions t
#     JOIN brands b
#     ON t.product_id = b.product_id
#     WHERE DATE_PART('year', date) = 2019 AND  brand = 'Adidas'
#     GROUP BY month, year
# )
# SELECT year, month, monthly_revenue, SUM(monthly_revenue) OVER(ORDER BY month) total_revenue
# FROM CTE
# ORDER BY 1, 2
# Out:
#  * postgresql://postgres:***@localhost:5432/Sports.Retailer.Project
# 12 rows affected.
# [(2019.0, 1.0, Decimal('36371.45'), Decimal('36371.45')),
#  (2019.0, 2.0, Decimal('29732.50'), Decimal('66103.95')),
#  (2019.0, 3.0, Decimal('34094.44'), Decimal('100198.39')),
#  (2019.0, 4.0, Decimal('30344.23'), Decimal('130542.62')),
#  (2019.0, 5.0, Decimal('36875.62'), Decimal('167418.24')),
#  (2019.0, 6.0, Decimal('29961.01'), Decimal('197379.25')),
#  (2019.0, 7.0, Decimal('34379.82'), Decimal('231759.07')),
#  (2019.0, 8.0, Decimal('34397.77'), Decimal('266156.84')),
#  (2019.0, 9.0, Decimal('30147.49'), Decimal('296304.33')),
#  (2019.0, 10.0, Decimal('33544.93'), Decimal('329849.26')),
#  (2019.0, 11.0, Decimal('34286.24'), Decimal('364135.50')),
#  (2019.0, 12.0, Decimal('35529.40'), Decimal('399664.90'))]

# %%
# PART 2
# Create a query that will produce a table showing the daily moving average for the month of May in 2018.

# %%
# I first created a table showing the daily revenue for the month of May in 2018. 
# I used a window function that calculates the moving average for 31 days (whole month of May).

# %%
# %%sql
# WITH CTE AS
# (
#    SELECT date, SUM(sale_price) as daily_revenue
#    FROM transactions t
#    JOIN brands b
#    ON t.product_id = b.product_id
#    WHERE DATE_PART('year', date) = 2018 AND DATE_PART('month', date) = 5
#    GROUP BY date
# )
# SELECT date, daily_revenue, ROUND(AVG(daily_revenue) OVER W, 2) AS moving_daily_average
# FROM CTE
# WINDOW W AS (ORDER BY DATE_PART('month', date) ROWS BETWEEN 31 PRECEDING AND CURRENT ROW)
# ORDER BY date
# Out:
#  * postgresql://postgres:***@localhost:5432/Sports.Retailer.Project
# 31 rows affected.
# [(datetime.date(2018, 5, 1), Decimal('1624.97'), Decimal('1624.97')),
#  (datetime.date(2018, 5, 2), Decimal('936.06'), Decimal('1280.52')),
#  (datetime.date(2018, 5, 3), Decimal('2071.44'), Decimal('1544.16')),
#  (datetime.date(2018, 5, 4), Decimal('1822.21'), Decimal('1613.67')),
#  (datetime.date(2018, 5, 5), Decimal('1591.29'), Decimal('1609.19')),
#  (datetime.date(2018, 5, 6), Decimal('1339.85'), Decimal('1564.30')),
#  (datetime.date(2018, 5, 7), Decimal('1661.78'), Decimal('1578.23')),
#  (datetime.date(2018, 5, 8), Decimal('1010.68'), Decimal('1507.29')),
#  (datetime.date(2018, 5, 9), Decimal('1136.52'), Decimal('1466.09')),
#  (datetime.date(2018, 5, 10), Decimal('1433.61'), Decimal('1462.84')),
#  (datetime.date(2018, 5, 11), Decimal('1198.87'), Decimal('1438.84')),
#  (datetime.date(2018, 5, 12), Decimal('1088.31'), Decimal('1409.63')),
#  (datetime.date(2018, 5, 13), Decimal('1876.57'), Decimal('1445.55')),
#  (datetime.date(2018, 5, 14), Decimal('1415.02'), Decimal('1443.37')),
#  (datetime.date(2018, 5, 15), Decimal('1424.32'), Decimal('1442.10')),
#  (datetime.date(2018, 5, 16), Decimal('1271.93'), Decimal('1431.46')),
#  (datetime.date(2018, 5, 17), Decimal('1135.20'), Decimal('1414.04')),
#  (datetime.date(2018, 5, 18), Decimal('1348.70'), Decimal('1410.41')),
#  (datetime.date(2018, 5, 19), Decimal('1795.67'), Decimal('1430.68')),
#  (datetime.date(2018, 5, 20), Decimal('1459.80'), Decimal('1432.14')),
#  (datetime.date(2018, 5, 21), Decimal('1502.96'), Decimal('1435.51')),
#  (datetime.date(2018, 5, 22), Decimal('1133.69'), Decimal('1421.79')),
#  (datetime.date(2018, 5, 23), Decimal('1212.38'), Decimal('1412.69')),
#  (datetime.date(2018, 5, 24), Decimal('1988.31'), Decimal('1436.67')),
#  (datetime.date(2018, 5, 25), Decimal('1119.64'), Decimal('1423.99')),
#  (datetime.date(2018, 5, 26), Decimal('1559.13'), Decimal('1429.19')),
#  (datetime.date(2018, 5, 27), Decimal('1505.02'), Decimal('1432.00')),
#  (datetime.date(2018, 5, 28), Decimal('1190.07'), Decimal('1423.36')),
#  (datetime.date(2018, 5, 29), Decimal('1472.83'), Decimal('1425.06')),
#  (datetime.date(2018, 5, 30), Decimal('952.21'), Decimal('1409.30')),
#  (datetime.date(2018, 5, 31), Decimal('1269.49'), Decimal('1404.79'))]

# %%
                                                # PROBLEM 15 #
# PART 1
# Which day has the record for most products sold?

# %%
# We can solve this problem using the window function ROW_NUMBER(), thus we don't need a GROUP BY statement.
# This shows that the online retailer sold the most products on July 21, 2019.

# %%
# %%sql
# WITH CTE AS
# (
# 	SELECT date, ROW_NUMBER() OVER(PARTITION BY date) AS number_of_products_sold
# 	FROM transactions
# )
# SELECT date, number_of_products_sold
# FROM CTE
# WHERE number_of_products_sold = (SELECT MAX(number_of_products_sold) FROM CTE)
# Out:
#  * postgresql://postgres:***@localhost:5432/Sports.Retailer.Project
# 1 rows affected.
# [(datetime.date(2019, 7, 21), 40)]

# %%
# PART 2
# Rank the products having sold the most items.

# %%
# I used the DENSE_RANK() window function to solve this problem. 
# We also need a COUNT function, join transactions and info tables together and group by product_name.
# We see a total of 78 different ranks.

# %%
# %%sql
# SELECT product_name, COUNT(*) AS number_of_products, DENSE_RANK() OVER(ORDER BY COUNT(*) DESC)
# FROM transactions t
# JOIN info i
# ON t.product_id = i.product_id
# GROUP BY product_name
#  ('Nike Air VaporMax 2019', 16, 63),
#  ("Women's adidas Running Edge Flex Shoes", 16, 63),
#  ("MEN'S ADIDAS OUTDOOR TERREX CMTK SHOES", 16, 63),
#  ("Men's adidas Originals Stan Smith Recon Shoes", 16, 63),
#  ('Nike Air Zoom SuperRep', 16, 63),
#  ("Women's adidas Running SenseBounce+ Shoes", 16, 63),
#  ("Men's Sport Inspired Blaze Runner Shoes", 16, 63),
#  ("MEN'S ADIDAS RUNNING ZETA 1.0 SHOES", 16, 63),
#  ("Men's Basketball Own The Game Shoes", 16, 63),
#  ("Women's adidas Sport Inspired Advantage Base Shoes", 16, 63),
#  ("Men's adidas Originals White Mountaineering Nite Jogger Shoes", 16, 63),
#  ("WOMEN'S ADIDAS SPORT INSPIRED RUN 70S SHOES", 16, 63),
#  ("WOMEN'S ADIDAS SWIM EEZAY DOTS FLIP-FLOPS", 16, 63),
#  ("Men's adidas Originals Deerupt Runner Shoes", 16, 63),
#  ('Nike Mercurial Superfly 7 Academy TF', 16, 63),
#  ("Men's adidas Running Argecy Shoes", 16, 63),
#  ("Men's Sport Inspired Advantage Base Shoes", 16, 63),
#  ("MEN'S ADIDAS ORIGINALS MARATHON X 5923 SHOES", 16, 63),
#  ("Men's adidas Football Copa 19.3 Firm Ground Cleats", 16, 63),
#  ("WOMEN'S ADIDAS ORIGINALS NMD_R1 STLT PRIMEKNIT SHOES", 16, 63),
#  ("Women's ADIDAS ORIGINALS COURTVANTAGE VULCANIZED SHOES", 16, 63),
#  ("MEN'S ADIDAS RUNNING ADISTARK 3.0 SHOES", 16, 63),
#  ('Nike Epic Phantom React Flyknit', 16, 63),
#  ("Men's adidas Originals POD-S3.2 ML Shoes", 16, 63),
#  ('NikeCourt Air Zoom Vapor X', 16, 63),
#  ("MEN'S ADIDAS ORIGINALS FUTUREPACER SHOES", 16, 63),
#  ("Men's adidas Originals 3ST.004 Shoes", 16, 63),
#  ("Men's adidas Running Alphabounce Instinct Shoes", 15, 64),
#  ("Men's Sport Inspired Advantage Shoes", 15, 64),
#  ('Nike Joyride Dual Run', 15, 64),
#  ("MEN'S ADIDAS ORIGINALS TEMPER RUN SHOES", 15, 64),
#  ("Men's adidas Training AlphaBounce Trainers", 15, 64),
#  ('Nike Odyssey React Flyknit 2', 15, 64),
#  ("WOMEN'S ADIDAS ORIGINALS EVERYN SHOES", 15, 64),
#  ("Men's adidas Originals 424 SC Premiere Shoes", 15, 64),
#  ('Nike Wildhorse 6', 15, 64),
#  ("Women's adidas Sport Inspired Farm Rio Advantage Shoes", 15, 64),
#  ("MEN'S ADIDAS ORIGINALS X_PLR SHOES", 15, 64),
#  ("Men's adidas Football Predator 19.1 Firm Ground Cleats", 15, 64),
#  ('NikeCourt Air Max Wildcard', 15, 64),
#  ("Men's adidas Sport Inspired Lite Racer Clean Shoes", 15, 64),
#  ("MEN'S ADIDAS ORIGINALS RISING STAR X R1 SHOES", 15, 64),
#  ("Men's adidas Running PureBounce+ Clima Shoes", 15, 64),
#  ('Nike Zoom Pegasus Turbo Shield', 15, 64),
#  ("Men's adidas Originals White Mountaineering X Terrex Agravic Speed+ Shoes", 15, 64),
#  ("Men's adidas Sport Inspired Netpoint Shoes", 15, 64),
#  ("Men's adidas Running Pureboost DPR Shoes", 15, 64),
#  ('Nike Air Force 1 GORE-TEX ®', 15, 64),
#  ("men's ADIDAS ORIGINALS PW HU HOLI STAN SMITH SHOES", 15, 64),
#  ("Women's adidas Originals Samba OG Shoes", 15, 64),
#  ("Men's adidas Sport Inspired Bball 90s Shoes", 15, 64),
#  ("men's ADIDAS SKATEBOARDING MATCHCOURT RX VULCANIZED SHOES", 15, 64),
#  ('Nike Air Max Tailwind IV', 15, 64),
#  ("Men's Pharrell Williams x adidas Originals Running Solar Hu PRD Shoes", 15, 64),
#  ('Nike Air Max Plus III', 15, 64),
#  ("Men's Sport Inspired Glarus Shoes", 15, 64),
#  ('Nike Air Zoom Winflo 6', 15, 64),
#  ("Men's adidas Adipower Vector Mid 20 Shoes", 15, 64),
#  ('Nike React Element 55', 15, 64),
#  ("Women's adidas Running Aseerun Shoes", 15, 64),
#  ("Women's adidas Sport Inspired Yking 2.0 Shoes", 15, 64),
#  ("Men's adidas Running Solar Glide 19 Shoes", 15, 64),
#  ("Women's adidas by Stella Mccartney Running UltraBoost 20 Shoes", 15, 64),
#  ("MEN'S ADIDAS RUNNING PUARO SHOES", 14, 65),
#  ("Men's adidas Originals Earlham SPZL Shoes", 14, 65),
#  ("Men's adidas Tennis Gumption III Shoes", 14, 65),
#  ("Men's adidas Tennis CourtJam Bounce Shoes", 14, 65),
#  ("Men's adidas Tennis Gumption II Shoes", 14, 65),
#  ("Men's adidas Football Copa 20.3 Firm Ground Boots", 14, 65),
#  ("Women's adidas Outdoor Mobe Sandals", 14, 65),
#  ("Men's Running Kalus 1.0 Shoes", 14, 65),
#  ("Women's adidas Sport Inspired VS Advantage Clean Shoes", 14, 65),
#  ("Men's adidas Basketball Streetcheck Shoes", 14, 65),
#  ("Women's adidas Originals NMD_R1 Primeknit Shoes", 14, 65),
#  ('Nike Air Max 200', 14, 65),
#  ('Air Jordan XXXIII', 14, 65),
#  ('Unisex adidas Originals Adi-Ease Shoes', 14, 65),
#  ('Nike Air Zoom Pegasus 36 Trail', 14, 65),
#  ("Women's adidas ORIGINALS ZX FLUX ADV VERVE Low Shoes", 14, 65),
#  ("MEN'S ADIDAS OUTDOOR SIKII SHOES", 14, 65),
#  ("Men's adidas Originals by Alexander Wang Futureshell Shoes", 14, 65),
#  ("Men's adidas Tennis Stin Indoor Shoes", 14, 65),
#  ("Men's adidas Football Copa 19.4 Firm Ground Cleats", 14, 65),
#  ("Men's adidas Running Stunn Shoes", 14, 65),
#  ("WOMEN'S ADIDAS PUREBOOST TRAINER SHOES", 14, 65),
#  ("Men's Sport Inspired Roguera Shoes", 14, 65),
#  ('Unisex adidas Originals Skateboarding Adi-Ease Shoes', 14, 65),
#  ("Men's adidas Originals Tubular Dusk Shoes", 14, 65),
#  ("Women's adidas Sport Inspired Lite Racer RBN Shoes", 14, 65),
#  ('Jordan Mars 270', 14, 65),
#  ("MEN'S ADIDAS ORIGINALS CONTINENTAL 80 SHOES", 14, 65),
#  ("Men's adidas Running 8K Shoes", 14, 65),
#  ("Men's adidas Sports Inspired Lite Racer Shoes", 14, 65),
#  ("Women's ADIDAS ORIGINALS CAMPUS SHOES", 14, 65),
#  ("Men's adidas Swim Ozor III Slippers", 14, 65),
#  ("Men's adidas Outdoor Trail Rocker Mid", 14, 65),
#  ('Jordan Break', 14, 65),
#  ("men's ADIDAS RUNNING TYLO SHOES", 14, 65),
#  ("Nike Air Force 1 Mid '07", 14, 65),
#  ("Women's adidas Originals Sleek Super Zip Shoes", 14, 65),
#  ("Women's adidas Originals EQT Gazelle Shoes", 14, 65),
#  ("Women's adidas originals TUBULAR SHADOW SHOES", 14, 65),
#  ("Men's adidas RUNNING COSMIC 2 SHOES", 14, 65),
#  ("Women's adidas Originals Magmur Runner Shoes", 14, 65),
#  ("Men's adidas Running SenseBounce+ Street Shoes", 14, 65),
#  ("Women's adidas Running Sponso Shoes", 14, 65),
#  ("Men's adidas Originals SL 80 Shoes", 14, 65),
#  ("Men's adidas Running Erdiga 3.0 Shoes", 14, 65),
#  ("Men's adidas Nova Run Shoes", 13, 66),
#  ("WOMEN'S ADIDAS RUNNING EDGE LUX 2 SHOES", 13, 66),
#  ("Women's ADIDAS ORIGINALS CAMPUS STITCH AND TURN SHOES", 13, 66),
#  ("Women's adidas Tennis Adizero Club Shoes", 13, 66),
#  ("WOMEN'S ADIDAS ORIGINALS EQT SUPPORT PRIMEKNIT 2/3 SHOES", 13, 66),
#  ("Men's adidas Originals Drop Step Shoes", 13, 66),
#  ("Men's adidas RUNNING NAYO SHOES", 13, 66),
#  ("WOMEN'S ADIDAS SWIM CLOUDFOAM FLIP FLOPS", 13, 66),
#  ('Nike ZoomX Vista Grind', 13, 66),
#  ('Air Jordan 5 Retro', 13, 66),
#  ('Nike Air Max 270', 13, 66),
#  ("Women's adidas Sport Inspired Crazychaos Shoes", 13, 66),
#  ("MEN'S ADIDAS RUNNING ARGECY SHOES", 13, 66),
#  ("WOMEN'S ADIDAS SPORT INSPIRED CLOUDFOAM ULTIMATE SHOES", 13, 66),
#  ("Women's adidas Running Asweerun Shoes", 13, 66),
#  ('Air Jordan 12 Retro', 13, 66),
#  ('Nike Air Zoom Winflo 5', 13, 66),
#  ("Men's adidas Sport Inspired Court Adapt Shoes", 13, 66),
#  ("Men's Running Duramo SL Shoes", 13, 66),
#  ('Nike Revolution 5 FlyEase', 13, 66),
#  ("Men's adidas Originals N-5923 Shoes", 13, 66),
#  ("Women's ADIDAS RUNNING EDGE LUX SHOES", 13, 66),
#  ("Women's adidas Originals Hypersleek Shoes", 13, 66),
#  ("Men's adidas Running Fluidcloud Neutral Shoes", 13, 66),
#  ("WoMEN'S adidas Outdoor TERREX VOYAGER DLX SHOES", 13, 66),
#  ("MEN'S ADIDAS RUNNING ERDIGA 3.0 SHOES", 13, 66),
#  ("Men's adidas Football Nemeziz Messi 19.3 Firm Ground Cleats", 11, 68),
#  ("Women's Running Asweego Shoes", 11, 68),
#  ("Men's adidas Sport Inspired Astro Lite 2.0 Shoes", 11, 68),
#  ("Women's adidas Running SenseBounce+ Street Shoes", 11, 68),
#  ("Men's Running Ancho Shoes", 11, 68),
#  ("Men's Football Nemeziz 19.4 Flexible Ground Cleats", 11, 68),
#  ("WOMEN'S ADIDAS RUNNING COSMIC 2 SHOES", 11, 68),
#  ("Men's Originals Action Sports Kiel Low Shoes", 11, 68),
#  ("Women's adidas Sport Inspired Grand Court Base Shoes", 11, 68),
#  ('Nike Epic Phantom React', 11, 68),
#  ('NikeCourt Royale', 11, 68),
#  ("Women's adidas Swim Eezay Flip-Flops", 11, 68),
#  ('LeBron 7 QS', 11, 68),
#  ("MEN'S ADIDAS SPORT INSPIRED VS ADVANTAGE SHOES", 11, 68),
#  ("WOMEN'S ADIDAS RUNNING PUREMOTION SHOES", 11, 68),
#  ("WOMEN'S ADIDAS RUNNING ALPHABOUNCE BEYOND SHOES", 11, 68),
#  ("Women's Originals Continental 80 Shoes", 11, 68),
#  ("Men's Running Galaxy 4 Shoes", 11, 68),
#  ("MEN'S ADIDAS FOOTBALL PREDATOR 19.1 FIRM GROUND BOOTS", 11, 68),
#  ("Men's adidas Nemeziz 19.3 Firm Ground Cleats", 11, 68),
#  ("Men's adidas Sport Inspired Lite Racer Slip-Ons", 11, 68),
#  ("Men's adidas Running PureBoost Shoes", 11, 68),
#  ("Women's adidas Running Adizero Boston 8 Shoes", 11, 68),
#  ("Men's Originals White Mountaineering Lxcon Shoes", 11, 68),
#  ("Men's adidas Originals Saint Florent BF Shoes", 11, 68),
#  ("Men's adidas Sport Inspired Kaptir Shoes", 11, 68),
#  ("Men's adidas Training Pureboost Trainer Shoes", 11, 68),
#  ("MEN'S ADIDAS FOOTBALL PREDATOR TANGO 18.1 TRAINERS", 11, 68),
#  ("Women's adidas Originals Sambarose Zip Shoes", 11, 68),
#  ("MEN'S ADIDAS ORIGINALS SUPERSTAR 80S CLEAN SHOES", 11, 68),
#  ("WOMEN'S ADIDAS ORIGINALS NMD_CS1 PRIMEKNIT SHOES", 11, 68),
#  ('Nike Mercurial Superfly 7 Academy IC', 11, 68),
#  ("Women's adidas Sport Inspired Questar Flow Shoes", 11, 68),
#  ('Nike Air Max 720 BETRUE', 11, 68),
#  ('Nike Air Max 95 Premium', 11, 68),
#  ("Women's adidas Sport Inspired Cloudfoam Pure Shoes", 11, 68),
#  ("Men's adidas Sport Inspired Questar BYD Shoes", 11, 68),
#  ("MEN'S ADIDAS ORIGINALS SUPERSTAR 80S RECON SHOES", 11, 68),
#  ('Nike Air Max 720 Waves', 11, 68),
#  ("MEN's adidas RUNNING Stardrift SHOES", 11, 68),
#  ("MEN'S ADIDAS RUNNING ALPHABOUNCE RC 2 SHOES", 11, 68),
#  ('Air Jordan 8 Retro', 11, 68),
#  ("Men's Originals Samba OG Shoes", 11, 68),
#  ("Men's adidas Originals Skateboarding Liberty Cup Shoes", 11, 68),
#  ("Women's adidas Running Pulseboost HD Winter Shoes", 9, 70),
#  ("Men's adidas Sport Inspired Throb Shoes", 9, 70),
#  ("Men's adidas Sports Inspired Lite Racer CLN Shoes", 9, 70),
#  ("Jordan 'Why Not?' Zer0.3 PF", 9, 70),
#  ('Unisex ADIDAS OUTDOOR TERREX JAWPAW SANDALS', 9, 70),
#  ("Women's adidas By Stella Mccartney PureBoost Trainers", 9, 70),
#  ("Men's adidas Football Nemeziz 19.3 Firm Ground Boots", 9, 70),
#  ("Men's Running EnergyFalcon Shoes", 9, 70),
#  ('PG 3 NASA', 9, 70),
#  ("MEN'S ADIDAS ORIGINALS EQT SUPPORT MID ADV PRIMEKNIT SHOES", 9, 70),
#  ("Men's adidas Tennis Woundrous II Shoes", 9, 70),
#  ('Nike Free RN 5.0 2020', 9, 70),
#  ("Men's Running Ultraboost PB Shoes", 9, 70),
#  ('Unisex adidas Originals Lucas Premiere Shoes', 9, 70),
#  ("Men's Running Spartum Shoes", 9, 70),
#  ("men's ADIDAS ORIGINALS PW TENNIS HU PK SHOES", 9, 70),
#  ("WOMEN'S ADIDAS RUNNING AEROBOUNCE 2 SHOES", 9, 70),
#  ("Men's Running Adispree 5.0 Shoes", 9, 70),
#  ("Men's Running Thrum Shoes", 9, 70),
#  ('Nike Solarsoft', 9, 70),
#  ("Women's Originals Sleek Shoes", 9, 70),
#  ('Nike Air Max Verona', 9, 70),
#  ("Men's adidas Football X 19.4 Indoor Shoes", 9, 70),
#  ("Women's adidas Sport Inspired Grand Court Shoes", 9, 70),
#  ("WOMEN'S ADIDAS ORIGINALS TUBULAR SHADOW CK SHOES", 9, 70),
#  ("Men's adidas ORIGINALS ACTION SPORTS ADIEASE LOW - SHOES", 9, 70),
#  ('Nike Potential 3', 9, 70),
#  ("Women's adidas Originals Samabarose Shoes", 9, 70),
#  ("Men's adidas Basketball Dame 5 Shoes", 9, 70),
#  ("Nike Air Force 1 '07 Premium", 9, 70),
#  ("Men's Sport Inspired Court Adapt Shoes", 9, 70),
#  ("men's ADIDAS RUNNING SUPERNOVA SHOES", 9, 70),
#  ('Nike SB Blazer Low GT', 9, 70),
#  ("Men's adidas Originals Tyshawn Shoes", 9, 70),
#  ("Men's adidas Running Kivaro 1 shoes", 9, 70),
#  ('Nike Air VaporMax SE', 9, 70),
#  ("Women's adidas Sport Inspired Court 70s Shoes", 9, 70),
#  ("Women's adidas Originals Superstar Slip-On Shoes", 9, 70),
#  ('Unisex ADIDAS SKATEBOARDING ADI-EASE VULCANIZED SHOES', 9, 70),
#  ('Nike Air Max 90 FlyEase', 9, 70),
#  ("men's ADIDAS RUNNING LEGUS 1 SHOES", 9, 70),
#  ("Women's adidas Running Solar Blaze Shoes", 9, 70),
#  ("Men's adidas Running Spartum Shoes", 9, 70),
#  ("Men's adidas Sport Inspired Zelt SL 2.0 Slip-Ons", 9, 70),
#  ("Men's adidas Football Nemeziz 18.4 Flexible Ground Cleats", 9, 70),
#  ('Nike Drop-Type', 9, 70),
#  ("Men's adidas Running AlphaBounce RC 2 Shoes", 9, 70),
#  ('Unisex adidas Swim Adissage Slides', 9, 70),
#  ('Nike Benassi JDI', 9, 70),
#  ("MEN'S ADIDAS RUNNING ENERGY CLOUD 2 SHOES", 9, 70),
#  ("WOMEN'S ADIDAS ORIGINALS STAN SMITH SOCK PK SHOES", 9, 70),
#  ("WOMEN'S ADIDAS ORIGINALS POD-S3.1 SHOES", 9, 70),
#  ("Men's adidas Swim Ozor II Slippers", 9, 70),
#  ("Men's adidas Originals Rivalry Shoes", 9, 70),
#  ("men's ADIDAS ORIGINALS ZX FLUX PK SHOES", 9, 70),
#  ("Women's Tennis Laceless Hard Court Shoes", 9, 70),
#  ("Women's adidas Originals Swift Run RF Shoes", 9, 70),
#  ('Nike Tiempo Legend 8 Academy MG', 9, 70),
#  ('Nike Pre-Love O.X.', 9, 70),
#  ("Women's adidas by Steall Mccartney Running Ultraboost T.S. Shoes", 9, 70),
#  ("Men's adidas Outdoor Ediffin II Sandals", 9, 70),
#  ('Jordan Aerospace 720', 9, 70),
#  ("Men's adidas Football Copa 19+ Firm Ground Cleats", 9, 70),
#  ('Nike Air Huarache', 9, 70),
#  ('Nike Phantom Vision Academy Dynamic Fit TF', 9, 70),
#  ("Men's Running Hellion Z Shoes", 9, 70),
#  ("Women's adidas Originals EQT Support 91/18 Shoes", 9, 70),
#  ("Men's adidas Swim Bise Slippers", 8, 71),
#  ('Nike Xarr', 8, 71),
#  ("Women's Sport Inspired QT Racer Shoes", 8, 71),
#  ("Men's adidas Football Nemeziz 19.1 Firm Ground Cleats", 8, 71),
#  ("MEN'S ADIDAS ORIGINALS EQT_ZX SHOES", 8, 71),
#  ("Men's Football Copa 20.3 Firm Ground Cleats", 8, 71),
#  ("Men's adidas Originals CountryxKamanda Shoes", 8, 71),
#  ("Men's Outdoors Rigi Shoes", 8, 71),
#  ('Nike x Olivia Kim Air Max 98', 8, 71),
#  ("Women's adidas Running Alphabounce+ Parley Shoes", 8, 71),
#  ("Men's adidas RUNFALCON Shoes", 8, 71),
#  ("Women's Running SL 20 Shoes", 8, 71),
#  ("men's ADIDAS FOOTBALL NEMEZIZ MESSI 17.1 FG SHOES", 8, 71),
#  ('Nike Air Zoom Pegasus 36 Premium Rise', 8, 71),
#  ('Kyrie 5 x Bandulu', 8, 71),
#  ('Nike Legend React', 8, 71),
#  ("Women's adidas Running Edgebounce 1.5 Shoes", 8, 71),
#  ("Men's adidas Running Astrarun Shoes", 8, 71),
#  ('Nike Air Max Dia NRG', 8, 71),
#  ('Unisex adidas Originals Skateboarding Sabalo Shoes', 8, 71),
#  ('Nike Air Max2 Light', 8, 71),
#  ("Men's adidas Sports Inspired Hoops 2.0 Shoes", 8, 71),
#  ('LeBron 17', 8, 71),
#  ('Unisex adidas Originals Skateboarding 2MC Shoes', 8, 71),
#  ("Women's adidas Tennis Courtsmash Shoes", 8, 71),
#  ("Men's Running SL 20 Shoes", 8, 71),
#  ("Men's adidas Running Edge PR Shoes", 8, 71),
#  ('Nike In-Season TR 9', 8, 71),
#  ("WOMEN'S ADIDAS RUNNING PUREBOUNCE+ STREET SHOES", 7, 72),
#  ('Kyrie Low 2', 7, 72),
#  ("Men's adidas Adilette Comfort Adjustable Slides", 7, 72),
#  ('Nike React Presto Premium', 7, 72),
#  ('Nike AF-1 Shadow SE', 7, 72),
#  ("Women's Originals Superstar Bold Shoes", 7, 72),
#  ("Women's Sport Inspired Grand Court Shoes", 7, 72),
#  ("WOMEN's adidas ORIGINALS TUBULAR DAWN SHOES", 7, 72),
#  ("Men's Originals Stan Smith Human Made Shoes", 7, 72),
#  ("Men's adidas Sport Inspired Hoops 2.0 Shoes", 7, 72),
#  ('Nike x Carhartt WIP Air Max 95', 7, 72),
#  ("Men's adidas Running Pureboost RBL Shoes", 7, 72),
#  ('Nike Air Force 1 Sage Low', 7, 72),
#  ("men's ADIDAS RUNNING HELKIN 3 SHOES", 7, 72),
#  ('Air Jordan 1 Mid SE', 7, 72),
#  ('Nike P-6000 Icon Clash', 7, 72),
#  ("Men's adidas Originals Seeley Shoes", 7, 72),
#  ("Women's Running Duramo 9 Shoes", 7, 72),
#  ("Men's adidas Football Nemeziz 19.3 Turf Boots", 7, 72),
#  ("Men's Running Dectron Shoes", 7, 72),
#  ('Unisex adidas ORIGINALS KIEL SHOES', 7, 72),
#  ('Nike iSPA React', 7, 72),
#  ('Unisex Adidas ORIGINALS SKATEBOARDING ADI-EASE VULCANIZED SHOES', 7, 72),
#  ('Nike Air Max 90 QS', 7, 72),
#  ('Kids-Unisex Running RapidaRun Knit EL Shoes', 7, 72),
#  ("WOMEN'S ADIDAS ORIGINALS FLB_RUNNER SHOES", 7, 72),
#  ("Men's adidas Outdoor Volantis II Shoes", 7, 72),
#  ('Nike React Metcon AMP', 7, 72),
#  ("Men's adidas Football Predator 19.1 Trainers", 7, 72),
#  ('Nike Pegasus 36 FlyEase (Extra Wide)', 7, 72),
#  ('Unisex adidas Running Adizero RC Shoes', 7, 72),
#  ("Men's Football Predator 20.4 Flexible Ground Shoes", 7, 72),
#  ("WOMEN'S ADIDAS OUTDOOR ELEVATE SANDALS", 7, 72),
#  ("MEN'S ADIDAS SPORT INSPIRED FUSION FLOW SHOES", 7, 72),
#  ("Men's adidas Originals 424 Pro Model Shoes", 7, 72),
#  ('Nike Zoom Rival Fly 2', 7, 72),
#  ('Nike SB Dunk High Pro', 7, 72),
#  ('Nike x MMW Joyride CC3 Setter', 7, 72),
#  ("MEN'S ADIDAS FOOTBALL NEMEZIZ MESSI 18.4 FLEXIBLE GROUND BOOTS", 7, 72),
#  ("WOMEN'S ADIDAS SPORT INSPIRED ENERGY CLOUD V SHOES", 7, 72),
#  ('Nike Air Max 270 SE', 7, 72),
#  ("Men's Basketball Gametalker Shoes", 7, 72),
#  ("Men's Originals Crazy BYW X 2.0 Shoes", 7, 72),
#  ...]

# %%
# We can also use RANK function instead of DENSE_RANK. 
# I prefer DENSE_RANK, since RANK leaves gaps between the values. If we have two items with rank of 13, the next rank will be 15.

# %%
# %%sql
# SELECT product_name, COUNT(*) AS number_of_products, RANK() OVER(ORDER BY COUNT(*) DESC)
# FROM transactions t
# JOIN info i
# ON t.product_id = i.product_id
# GROUP BY product_name
# Out:
#  * postgresql://postgres:***@localhost:5432/Sports.Retailer.Project
# 1493 rows affected.
# [("Men's adidas Originals Supercourt Shoes", 125, 1),
#  ("Women's adidas Originals Sleek Shoes", 107, 2),
#  ("Men's adidas Originals Continental 80 Shoes", 102, 3),
#  ("Women's adidas Originals Sambarose Shoes", 101, 4),
#  ('Unisex adidas Originals Marathon Tech Shoes', 96, 5),
#  ("Men's adidas Originals Stan Smith Shoes", 83, 6),
#  ("Women's adidas Originals NMD_R1 Shoes", 81, 7),
#  ("Men's adidas Originals Rivalry Low Shoes", 80, 8),
#  ('Nike Air Max 90', 79, 9),
#  ("Men's adidas Originals Forest Grove Shoes", 76, 10),
#  ("Women's adidas Originals Falcon Shoes", 75, 11),
#  ("Men's adidas Sport Inspired VL Court 2.0 Shoes", 72, 12),
#  ("Women's adidas Originals Continental 80 Shoes", 71, 13),
#  ("Men's adidas Running Galaxy 4 Shoes", 71, 13),
#  ('Unisex adidas Originals Skateboarding 3MC Shoes', 70, 15),
#  ("Men's adidas Running Ultraboost 19 Shoes", 69, 16),
#  ("Men's adidas Running Duramo 9 Shoes", 68, 17),
#  ("Women's adidas Originals POD-S3.1 Shoes", 67, 18),
#  ("Men's adidas Sport Inspired Grand Court Shoes", 67, 18),
#  ("Women's adidas Originals Stan Smith Shoes", 61, 20),
#  ("Women's adidas Originals Superstar Shoes", 61, 20),
#  ("Men's adidas Running EnergyFalcon Shoes", 60, 22),
#  ("Men's adidas Sport Inspired Drogo Shoes", 59, 23),
#  ("Men's adidas Running Nepton 2.0 Shoes", 58, 24),
#  ("Men's adidas Sport Inspired Archivo Shoes", 58, 24),
#  ("Women's adidas Originals I-5923 Shoes", 58, 24),
#  ("Men's adidas Running Asweerun Shoes", 57, 27),
#  ("WOMEN'S ADIDAS ORIGINALS SAMBAROSE SHOES", 57, 27),
#  ("Men's adidas Sport Inspired Blaze Runner Shoes", 57, 27),
#  ("Men's adidas Originals Superstar Shoes", 56, 30),
#  ("Men's adidas Outdoor Elevate 2018 Sandals", 56, 30),
#  ("Women's adidas Originals Supercourt Shoes", 55, 32),
#  ('Unisex adidas Originals Continental Vulc Shoes', 55, 32),
#  ("Men's adidas Originals Skateboarding Seeley Shoes", 55, 32),
#  ("Men's adidas Originals NMD_R1 Shoes", 54, 35),
#  ("Men's adidas Originals Yung-1 Shoes", 54, 35),
#  ("Men's adidas Outdoor Naha Shoes", 54, 35),
#  ("Women's adidas Originals Rivalry Low Shoes", 54, 35),
#  ("Men's adidas Sport Inspired Grand Court Base Shoes", 53, 39),
#  ("Men's adidas Originals EQT Gazelle Shoes", 52, 40),
#  ("Men's adidas Originals U_Path Run Shoes", 52, 40),
#  ("Men's adidas Running SenseBoost GO Shoes", 52, 40),
#  ('Nike Air Max 270 React', 51, 43),
#  ("Women's adidas Running Ultraboost 19 Shoes", 51, 43),
#  ("Men's adidas Running Hyperon 1.0 Shoes", 23, 217),
#  ("MEN'S ADIDAS SPORT INSPIRED LITE RACER SHOES", 23, 217),
#  ("Men's adidas Running PulseBoost HD Ltd Shoes", 23, 217),
#  ("Men's Football Predator 20.3 Turf Shoes", 23, 217),
#  ("Women's adidas Sport Inspired Cloudfoam Racer TR Shoes", 23, 217),
#  ("Men's adidas Sports Inspired Hoops 2.0 Mid Shoes", 23, 217),
#  ("Men's adidas Running Solarboost 19 Shoes", 23, 217),
#  ("Women's adidas Running Asweego Shoes", 23, 217),
#  ('Nike Zoom Pegasus Turbo 2', 23, 217),
#  ("Men's adidas Running PulseBoost HD Shoes", 23, 217),
#  ("Men's adidas Originals Samba OG Shoes", 23, 217),
#  ("Men's adidas Originals Ozweego TR Shoes", 23, 217),
#  ("Men's adidas Sport Inspired Drogo 2.0 Shoes", 23, 217),
#  ("Women's Sport Inspired Lite Racer 2.0 Shoes", 22, 242),
#  ("Men's adidas Originals Superstar MG Shoes", 22, 242),
#  ("Women's adidas Sport Inspired Arcadeis Shoes", 22, 242),
#  ('Nike Metcon 5 AMP', 22, 242),
#  ("Women's adidas Originals ZX Torsion Shoes", 22, 242),
#  ("Women's Running Ultraboost 20 Shoes", 22, 242),
#  ("Men's adidas Running SenseBounce+ Shoes", 22, 242),
#  ("Women's adidas Sport Inspired Videll Shoes", 22, 242),
#  ("Men's adidas Originals X_PLR S Shoes", 22, 242),
#  ("Men's adidas Running Dracon Shoes", 22, 242),
#  ("Women's adidas Swimming Eezay 2019 Slippers", 22, 242),
#  ("Men's adidas Original X_PLR Shoes", 22, 242),
#  ("Men's adidas Running Kivaro 1 Shoes", 22, 242),
#  ("Men's adidas Running Zeta 2.0 Shoes", 22, 242),
#  ("men's ADIDAS ORIGINALS STAN SMITH shoes", 22, 242),
#  ("Men's adidas Originals Campus Shoes", 22, 242),
#  ("Men's adidas Sport Inspired Crazychaos Shoes", 22, 242),
#  ("MEN'S ADIDAS SPORT INSPIRED QUESTAR DRIVE SHOES", 22, 242),
#  ("Men's adidas Tennis Courtsmash Shoes", 22, 242),
#  ("Men's adidas Running Kollide Shoes", 22, 242),
#  ("Women's adidas Sport Inspired Drogo Shoes", 22, 242),
#  ('LeBron Soldier 13 SFG', 22, 242),
#  ("Men's adidas Sport Inspired Lyrid Slip-ons", 22, 242),
#  ('Nike MX-720-818', 22, 242),
#  ("Men's adidas Football X 18.1 Firm Ground Cleats", 22, 242),
#  ("men's ADIDAS SKATEBOARDING SEELEY VULCANIZED SHOES", 22, 242),
#  ("MEN'S ADIDAS RUNNING ASWEERUN SHOES", 21, 268),
#  ("Women's adidas Originals U_Path Run Shoes", 21, 268),
#  ('Nike Flex RN 2019', 21, 268),
#  ("Women's adidas Sport Inspired Kaptir X Shoes", 21, 268),
#  ("WOMEN'S ADIDAS SPORT INSPIRED ADVANTAGE CLEAN QT SHOES", 21, 268),
#  ("Women's adidas Swim Adilette Aqua Slides", 21, 268),
#  ("Men's Outdoor Wind Chaser II Shoes", 21, 268),
#  ("Men's Running Duramo 2.0 Shoes", 16, 406),
#  ("WOMEN'S ADIDAS RUNNING QUESA SHOES", 16, 406),
#  ('Nike Mercurial Vapor 13 Elite FG', 16, 406),
#  ('Nike Air VaporMax 2019', 16, 406),
#  ("Women's adidas Running Edge Flex Shoes", 16, 406),
#  ("MEN'S ADIDAS OUTDOOR TERREX CMTK SHOES", 16, 406),
#  ("Men's adidas Originals Stan Smith Recon Shoes", 16, 406),
#  ('Nike Air Zoom SuperRep', 16, 406),
#  ("Women's adidas Running SenseBounce+ Shoes", 16, 406),
#  ("Men's Sport Inspired Blaze Runner Shoes", 16, 406),
#  ("MEN'S ADIDAS RUNNING ZETA 1.0 SHOES", 16, 406),
#  ("Men's Basketball Own The Game Shoes", 16, 406),
#  ("Women's adidas Sport Inspired Advantage Base Shoes", 16, 406),
#  ("Men's adidas Originals White Mountaineering Nite Jogger Shoes", 16, 406),
#  ("WOMEN'S ADIDAS SPORT INSPIRED RUN 70S SHOES", 16, 406),
#  ("WOMEN'S ADIDAS SWIM EEZAY DOTS FLIP-FLOPS", 16, 406),
#  ("Men's adidas Originals Deerupt Runner Shoes", 16, 406),
#  ('Nike Mercurial Superfly 7 Academy TF', 16, 406),
#  ("Men's adidas Running Argecy Shoes", 16, 406),
#  ("Men's Sport Inspired Advantage Base Shoes", 16, 406),
#  ("MEN'S ADIDAS ORIGINALS MARATHON X 5923 SHOES", 16, 406),
#  ("Men's adidas Football Copa 19.3 Firm Ground Cleats", 16, 406),
#  ("WOMEN'S ADIDAS ORIGINALS NMD_R1 STLT PRIMEKNIT SHOES", 16, 406),
#  ("Women's ADIDAS ORIGINALS COURTVANTAGE VULCANIZED SHOES", 16, 406),
#  ("MEN'S ADIDAS RUNNING ADISTARK 3.0 SHOES", 16, 406),
#  ('Nike Epic Phantom React Flyknit', 16, 406),
#  ("Men's adidas Originals POD-S3.2 ML Shoes", 16, 406),
#  ('NikeCourt Air Zoom Vapor X', 16, 406),
#  ("MEN'S ADIDAS ORIGINALS FUTUREPACER SHOES", 16, 406),
#  ("Men's adidas Originals 3ST.004 Shoes", 16, 406),
#  ("Men's adidas Running Alphabounce Instinct Shoes", 15, 442),
#  ("Men's Sport Inspired Advantage Shoes", 15, 442),
#  ('Nike Joyride Dual Run', 15, 442),
#  ("MEN'S ADIDAS ORIGINALS TEMPER RUN SHOES", 15, 442),
#  ("Men's adidas Training AlphaBounce Trainers", 15, 442),
#  ('Nike Odyssey React Flyknit 2', 15, 442),
#  ("WOMEN'S ADIDAS ORIGINALS EVERYN SHOES", 15, 442),
#  ("Men's adidas Originals 424 SC Premiere Shoes", 15, 442),
#  ('Nike Wildhorse 6', 15, 442),
#  ("Women's adidas Sport Inspired Farm Rio Advantage Shoes", 15, 442),
#  ("MEN'S ADIDAS ORIGINALS X_PLR SHOES", 15, 442),
#  ("Men's adidas Football Predator 19.1 Firm Ground Cleats", 15, 442),
#  ('NikeCourt Air Max Wildcard', 15, 442),
#  ("Men's adidas Sport Inspired Lite Racer Clean Shoes", 15, 442),
#  ("WOMEN'S ADIDAS ORIGINALS FOREST GROVE SHOES", 11, 631),
#  ("Men's Sport Inspired PokÃ©mon Phosphere Shoes", 11, 631),
#  ("Men's adidas Football Nemeziz Messi 19.3 Firm Ground Cleats", 11, 631),
#  ("Women's Running Asweego Shoes", 11, 631),
#  ("Men's adidas Sport Inspired Astro Lite 2.0 Shoes", 11, 631),
#  ("Women's adidas Running SenseBounce+ Street Shoes", 11, 631),
#  ("Men's Running Ancho Shoes", 11, 631),
#  ("Men's Football Nemeziz 19.4 Flexible Ground Cleats", 11, 631),
#  ("WOMEN'S ADIDAS RUNNING COSMIC 2 SHOES", 11, 631),
#  ("Men's Originals Action Sports Kiel Low Shoes", 11, 631),
#  ("Women's adidas Sport Inspired Grand Court Base Shoes", 11, 631),
#  ('Nike Epic Phantom React', 11, 631),
#  ('NikeCourt Royale', 11, 631),
#  ("Women's adidas Swim Eezay Flip-Flops", 11, 631),
#  ('LeBron 7 QS', 11, 631),
#  ("MEN'S ADIDAS SPORT INSPIRED VS ADVANTAGE SHOES", 11, 631),
#  ("WOMEN'S ADIDAS RUNNING PUREMOTION SHOES", 11, 631),
#  ("WOMEN'S ADIDAS RUNNING ALPHABOUNCE BEYOND SHOES", 11, 631),
#  ("Women's Originals Continental 80 Shoes", 11, 631),
#  ("Men's Running Galaxy 4 Shoes", 11, 631),
#  ("MEN'S ADIDAS FOOTBALL PREDATOR 19.1 FIRM GROUND BOOTS", 11, 631),
#  ("Men's adidas Nemeziz 19.3 Firm Ground Cleats", 11, 631),
#  ("Men's adidas Sport Inspired Lite Racer Slip-Ons", 11, 631),
#  ("Men's adidas Running PureBoost Shoes", 11, 631),
#  ("Women's adidas Running Adizero Boston 8 Shoes", 11, 631),
#  ("Men's Originals White Mountaineering Lxcon Shoes", 11, 631),
#  ("Men's adidas Originals Saint Florent BF Shoes", 11, 631),
#  ("Men's adidas Sport Inspired Kaptir Shoes", 11, 631),
#  ("Men's adidas Training Pureboost Trainer Shoes", 11, 631),
#  ("MEN'S ADIDAS FOOTBALL PREDATOR TANGO 18.1 TRAINERS", 11, 631),
#  ("Women's adidas Originals Sambarose Zip Shoes", 11, 631),
#  ("MEN'S ADIDAS ORIGINALS SUPERSTAR 80S CLEAN SHOES", 11, 631),
#  ("WOMEN'S ADIDAS ORIGINALS NMD_CS1 PRIMEKNIT SHOES", 11, 631),
#  ('Nike Mercurial Superfly 7 Academy IC', 11, 631),
#  ("Women's adidas Sport Inspired Questar Flow Shoes", 11, 631),
#  ('Nike Air Max 720 BETRUE', 11, 631),
#  ('Nike Air Max 95 Premium', 11, 631),
#  ("Women's adidas Sport Inspired Cloudfoam Pure Shoes", 11, 631),
#  ("Men's adidas Sport Inspired Questar BYD Shoes", 11, 631),
#  ("MEN'S ADIDAS ORIGINALS SUPERSTAR 80S RECON SHOES", 11, 631),
#  ('Nike Air Max 720 Waves', 11, 631),
#  ("MEN's adidas RUNNING Stardrift SHOES", 11, 631),
#  ("MEN'S ADIDAS RUNNING ALPHABOUNCE RC 2 SHOES", 11, 631),
#  ('Air Jordan 8 Retro', 11, 631),
#  ("Men's Originals Samba OG Shoes", 11, 631),
#  ("Men's adidas Originals Skateboarding Liberty Cup Shoes", 11, 631),
#  ("Men's adidas Originals Adilette Slides", 11, 631),
#  ("Men's adidas RUNNING PUARO SHOES", 11, 631),
#  ('Nike x Hawkins High Cortez', 11, 631),
#  ("MEN'S adidas ORIGINALS NIZZA SHOES", 11, 631),
#  ("MEN'S adidas RUNNING KRAY 2 SHOES", 11, 631),
#  ("MEN'S ADIDAS ORIGINALS SPZL ZX 452 SHOES", 10, 690),
#  ("Women's adidas Originals Sleek Mid Shoes", 10, 690),
#  ("Men's adidas Running Nayo 1.0 shoes", 10, 690),
#  ('UNISEX ADIDAS ORIGINALS ADIEASE SHOES', 10, 690),
#  ("MEN'S ADIDAS OUTDOOR ELEVATE SANDALS", 10, 690),
#  ("men's adidas RUNNING LEGUS SHOES", 10, 690),
#  ("Men's Running Lace It Shoes", 10, 690),
#  ("MEN'S ADIDAS RUNNING ULTRABOOST SHOES", 10, 690),
#  ("MEN'S ADIDAS FOOTBALL COPA 18.1 FIRM GROUND CLEATS", 10, 690),
#  ("MEN'S ADIDAS ORIGINALS NMD_TS1 PRIMEKNIT SHOES", 10, 690),
#  ('Air Jordan 1 Jester XX Low Laced', 10, 690),
#  ("Women's adidas Originals Superstar Pure Shoes", 10, 690),
#  ('Unisex adidas Running Alphabounce+ Shoes', 10, 690),
#  ('Nike Air Force 1 SP', 10, 690),
#  ("MEN'S ADIDAS ORIGINALS 3ST.003 SHOES", 10, 690),
#  ('Nike Air Max 2017', 10, 690),
#  ("Women's adidas Sport Inspired Chaos Shoes", 10, 690),
#  ("MEN'S ADIDAS RUNNING LEGUS 1.0 SHOES", 10, 690),
#  ("Men's adidas Swimming Beach Print Maxout Slippers", 10, 690),
#  ("WoMen's adidas RUNNING KIVARO SL SHOES", 10, 690),
#  ("Men's adidas Originals STAN SMITH Low Shoes", 10, 690),
#  ('Nike React Element 55 Premium', 10, 690),
#  ("Men's Originals Swift Run Shoes", 10, 690),
#  ('Nike Zoom Rival Fly', 10, 690),
#  ('Nike React Sertu', 10, 690),
#  ("MEN'S ADIDAS FOOTBALL NEMEZIZ 18.1 FIRM GROUND BOOTS", 10, 690),
#  ('Nike TiempoX Lunar Legend VII Pro TF', 10, 690),
#  ("Women's adidas by Stella Mccartney Running UltraBoost X 3D Shoes", 10, 690),
#  ('Nike Air Skarn', 10, 690),
#  ("Men's adidas Sport Inspired Fusion Storm Shoes", 10, 690),
#  ("MEN'S ADIDAS RUNNING RYZO 4.0 SHOES", 10, 690),
#  ('Nike Air Max 98 LX', 10, 690),
#  ("Men's adidas Originals SC Premiere Gore-Tex Shoes", 10, 690),
#  ('Nike Tiempo Legend 8 Elite FG', 10, 690),
#  ("Men's Cricket Cri Hase Shoes", 10, 690),
#  ('Nike SB Blazer Low XT', 10, 690),
#  ('Nike ISPA Joyride Envelope', 10, 690),
#  ("Men's Sport Inspired Phosphere Shoes", 10, 690),
#  ('Air Jordan 14 Retro', 10, 690),
#  ("Men's adidas Football X 18.3 Firm Ground Boots", 10, 690),
#  ("Nike Air Force 1 '07 SE", 10, 690),
#  ("Men's adidas Sport Inspired Shoes", 10, 690),
#  ('Nike Zoom Fly Flyknit', 10, 690),
#  ("WOMEN'S ADIDAS ORIGINALS EQT ADV RACING SHOES", 10, 690),
#  ('Kids-Unisex adidas Tennis Adizero Club Shoes', 10, 690),
#  ('Nike Air Max Tailwind IV SP', 10, 690),
#  ("Men's adidas Running Thrum Shoes", 10, 690),
#  ("Men's adidas Running Weave Shoes", 10, 690),
#  ("Men's adidas Originals Pharrell Williams X BYW CNY Shoes", 10, 690),
#  ("WOMEN'S ADIDAS ORIGINALS EQT SUPPORT SOCK PRIMEKNIT SHOES", 10, 690),
#  ("Men's adidas Running Alphabounce+ Shoes", 10, 690),
#  ("Women's ADIDAS ORIGINALS STAN SMITH CUTOUT shoes", 10, 690),
#  ('Air Jordan 1 Mid', 10, 690),
#  ("Men's adidas Comfort Flip Flops", 10, 690),
#  ("Women's Running SL20 Shoes", 10, 690),
#  ("Kid's Unisex adidas Originals X_PLR Shoes", 10, 690),
#  ("Women's Running Focus Magnolia Shoes", 10, 690),
#  ("Women's adidas Training FitBounce Trainers", 10, 690),
#  ('Air Jordan 1 Nova XX', 10, 690),
#  ("Women's adidas Originals Superstar Pure LT Shoes", 10, 690),
#  ('Nike Zoom Pegasus Turbo 2 Rise', 10, 690),
#  ("Men's Sport Inspired Streetmighty Shoes", 10, 690),
#  ("Men's adidas Sport Inspired Questar Drive Shoes", 10, 690),
#  ("MEN'S ADIDAS ORIGINALS ZX930 X EQT SHOES", 10, 690),
#  ("Men's Outdoor Hoist Light Sandals", 10, 690),
#  ('NikeCourt Air Zoom Vapor Cage 4', 10, 690),
#  ("Men's adidas Originals ZX Flux Shoes", 10, 690),
#  ('Air Jordan 13 Retro Chinese New Year', 10, 690),
#  ("MEN'S ADIDAS BASKETBALL MARQUEE BOOST LOW SHOES", 10, 690),
#  ('Unisex Bascketball Pro Model 2G - Forbidden City Shoes', 10, 690),
#  ("Men's adidas Running Solar Glide Shoes", 10, 690),
#  ("Men's adidas Originals By Alexander Wang B-Ball Shoes", 10, 690),
#  ("Men's adidas Running Duramo 2.0 Shoes", 10, 690),
#  ("Men's adidas Basketball Pro Bounce Madness 2019 Shoes", 10, 690),
#  ("Women's ADIDAS ORIGINALS NMD_CS2 PK SHOES", 10, 690),
#  ("Women's adidas Running Alphabounce Instinct Shoes", 10, 690),
#  ('UNISEX adidas Originals Pharrell Williams Hu NMD Proud Shoes', 10, 690),
#  ("WOMEN'S ADIDAS TRAINING SOLAR LT TRAINERS", 10, 690),
#  ("Women's ADIDAS TENNIS BARRICADE CLUB SHOES", 10, 690),
#  ('Zoom Freak 1', 10, 690),
#  ('Nike Phantom Vision Club Dynamic Fit FG', 10, 690),
#  ("Women's adidas Originals Taekwondo Shoes", 9, 771),
#  ("Men's adidas Football Nemeziz 18.4 Flexible Ground Cleats", 9, 771),
#  ('Nike Drop-Type', 9, 771),
#  ("Men's adidas Running AlphaBounce RC 2 Shoes", 9, 771),
#  ('Unisex adidas Swim Adissage Slides', 9, 771),
#  ('Nike Benassi JDI', 9, 771),
#  ("MEN'S ADIDAS RUNNING ENERGY CLOUD 2 SHOES", 9, 771),
#  ("WOMEN'S ADIDAS ORIGINALS STAN SMITH SOCK PK SHOES", 9, 771),
#  ("WOMEN'S ADIDAS ORIGINALS POD-S3.1 SHOES", 9, 771),
#  ("Men's adidas Swim Ozor II Slippers", 9, 771),
#  ("Men's adidas Originals Rivalry Shoes", 9, 771),
#  ("men's ADIDAS ORIGINALS ZX FLUX PK SHOES", 9, 771),
#  ("Women's Tennis Laceless Hard Court Shoes", 9, 771),
#  ("Women's adidas Originals Swift Run RF Shoes", 9, 771),
#  ('Nike Tiempo Legend 8 Academy MG', 9, 771),
#  ('Nike Pre-Love O.X.', 9, 771),
#  ("Women's adidas by Steall Mccartney Running Ultraboost T.S. Shoes", 9, 771),
#  ("Men's adidas Outdoor Ediffin II Sandals", 9, 771),
#  ('Jordan Aerospace 720', 9, 771),
#  ("Men's adidas Football Copa 19+ Firm Ground Cleats", 9, 771),
#  ('Nike Air Huarache', 9, 771),
#  ('Nike Phantom Vision Academy Dynamic Fit TF', 9, 771),
#  ("Men's Running Hellion Z Shoes", 9, 771),
#  ("Women's adidas Originals EQT Support 91/18 Shoes", 9, 771),
#  ("Men's adidas Swim Bise Slippers", 8, 842),
#  ('Nike Xarr', 8, 842),
#  ("Women's Sport Inspired QT Racer Shoes", 8, 842),
#  ("Men's adidas Football Nemeziz 19.1 Firm Ground Cleats", 8, 842),
#  ("MEN'S ADIDAS ORIGINALS EQT_ZX SHOES", 8, 842),
#  ("Men's Football Copa 20.3 Firm Ground Cleats", 8, 842),
#  ("Men's adidas Originals CountryxKamanda Shoes", 8, 842),
#  ("Men's Outdoors Rigi Shoes", 8, 842),
#  ('Nike x Olivia Kim Air Max 98', 8, 842),
#  ("Women's adidas Running Alphabounce+ Parley Shoes", 8, 842),
#  ("Men's adidas RUNFALCON Shoes", 8, 842),
#  ("Women's Running SL 20 Shoes", 8, 842),
#  ("men's ADIDAS FOOTBALL NEMEZIZ MESSI 17.1 FG SHOES", 8, 842),
#  ('Nike Air Zoom Pegasus 36 Premium Rise', 8, 842),
#  ('Kyrie 5 x Bandulu', 8, 842),
#  ('Nike Legend React', 8, 842),
#  ("Women's adidas Running Edgebounce 1.5 Shoes", 8, 842),
#  ("Men's adidas Running Astrarun Shoes", 8, 842),
#  ('Nike Air Max Dia NRG', 8, 842),
#  ('Unisex adidas Originals Skateboarding Sabalo Shoes', 8, 842),
#  ('Nike Air Max2 Light', 8, 842),
#  ("Men's adidas Sports Inspired Hoops 2.0 Shoes", 8, 842),
#  ('LeBron 17', 8, 842),
#  ('Unisex adidas Originals Skateboarding 2MC Shoes', 8, 842),
#  ("Women's adidas Tennis Courtsmash Shoes", 8, 842),
#  ("Men's Running SL 20 Shoes", 8, 842),
#  ("Men's adidas Running Edge PR Shoes", 8, 842),
#  ('Nike In-Season TR 9', 8, 842),
#  ("Men's adidas Originals Samba RM Shoes", 8, 842),
#  ('LeBron 17 Low', 8, 842),
#  ("WOMEN'S ADIDAS SPORT INSPIRED QUESTAR RIDE SHOES", 8, 842),
#  ('Jordan Jumpman 2020 PF', 8, 842),
#  ("MEN'S ADIDAS FOOTBALL NEMEZIZ MESSI 18.3 FIRM GROUND BOOTS", 8, 842),
#  ('Nike Air Zoom Vomero 14', 8, 842),
#  ("Men's adidas Football Predator 19.3 Firm Ground Boots", 8, 842),
#  ("Men's Football Copa 20.4 Firm Ground Cleats", 8, 842),
#  ('Nike Free TR Ultra', 8, 842),
#  ("men's ADIDAS RUNNING CF ELEmen'sT RACE SHOES", 8, 842),
#  ("WOMEN'S ADIDAS ORIGINALS N-5923 SHOES", 8, 842),
#  ("MEN'S ADIDAS SPORT INSPIRED LITE RACER BYD SHOES", 8, 842),
#  ("Men's adidas Originals CAMPUS Low Shoes", 8, 842),
#  ("WOMEN'S ADIDAS SPORT INSPIRED COURTSET SHOES", 8, 842),
#  ("Men's adidas TRAINING DURAMO 8 LEATHER Low Shoes", 8, 842),
#  ('UNISEX ADIDAS ORIGINALS MARATHON X 5923 SHOES', 8, 842),
#  ('Nike Air Max 720 SE', 8, 842),
#  ('Nike ISPA Air Max 720', 8, 842),
#  ("men's Adidas RUNNING PUREBOOST DPR SHOES", 8, 842),
#  ("Women's adidas ORIGINALS EQT RACING Low Shoes", 8, 842),
#  ('Nike Mercurial Vapor 13 Academy TF', 8, 842),
#  ("Men's Running Staredge Shoes", 8, 842),
#  ("Men's Sport Inspired Caflaire Shoes", 8, 842),
#  ("MEN'S ADIDAS ORIGINALS TUBULAR DUSK SHOES", 8, 842),
#  ("Men's adidas Basketball Pro Bounce 2019 Shoes", 8, 842),
#  ("Men's adidas Tennis SoleMatch Bounce Hard Court Shoes", 8, 842),
#  ('Nike React Kenny 55', 8, 842),
#  ("Men's Running FluidFlow Shoes", 8, 842),
#  ('Nike Joyride CC3 Setter', 8, 842),
#  ("Women's ADIDAS ORIGINALS GAZELLE STITCH AND TURN SHOES", 8, 842),
#  ("Women's Sport Inspired Nebzed Shoes", 8, 842),
#  ("MEN'S ADIDAS SPORT INSPIRED VS SET MID SHOES", 8, 842),
#  ("WOMEN'S ADIDAS SPORT INSPIRED QUESTAR FLOW SHOES", 8, 842),
#  ("men's ADIDAS FOOTBALL NEMEZIZ 17.1 FG SHOES", 8, 842),
#  ('LeBron x John Elliott Icon', 8, 842),
#  ("Men's adidas ORIGINALS NMD_XR1 ADVENTURE SHOES", 8, 842),
#  ("WOMEN'S ADIDAS PUREBOOST X TRAINER 3.0 SHOES", 8, 842),
#  ("Men's adidas Basketball Streetflow Shoes", 8, 842),
#  ("Men's Running SenseBounce+ Ace Shoes", 8, 842),
#  ('Nike React Ianga', 8, 842),
#  ('Kyrie 5', 8, 842),
#  ("Men's Football X 19.4 Flexible Ground Cleats", 8, 842),
#  ("Men's adidas Sport Inspired Zeta 1.0 Shoes", 8, 842),
#  ("MEN'S ADIDAS SPORTS INSPIRED HOOPS 2.0 MID SHOES", 8, 842),
#  ('Nike Air Max 97 Utility', 8, 842),
#  ("Women's adidas PUREBOOST X ALL TERRAIN Shoes", 8, 842),
#  ("Men's adidas Originals Crazy BYW LVL X Pharrell Williams Shoes", 8, 842),
#  ('Nike Drop-Type Mid', 8, 842),
#  ("MEN'S ADIDAS RUNNING AEROBOUNCE PR SHOES", 8, 842),
#  ("Men's adidas Sport Inspired VS Advantage Shoes", 8, 842),
#  ('Nike x Undercover React Presto', 8, 842),
#  ('Nike Air Ghost Racer', 8, 842),
#  ("Women's adidas Originals SUPERSTAR CUT OUT Low Shoes", 8, 842),
#  ("MEN'S ADIDAS ORIGINALS SKATEBOARDING ADIEASE PREMIERE SHOES", 8, 842),
#  ('Nike Joyride Run Flyknit', 8, 842),
#  ("Men's Sports Inspired Hoops 2.0 Mid Shoes", 8, 842),
#  ("Men's adidas Originals Deerupt S Shoes", 8, 842),
#  ("men's ADIDAS ORIGINALS SWIFT RUN PK SHOES", 8, 842),
#  ("WOMEN'S ADIDAS RUNNING NEPTON 2.0 SHOES", 8, 842),
#  ('Nike Air Max 90 NS SE', 8, 842),
#  ("Men's Outdoor Terra Light Sandals", 8, 842),
#  ("Men's Originals Summer Adilette Slippers", 8, 842),
#  ("WOMEN'S ADIDAS RUNNING DURAMO 9 SHOES", 8, 842),
#  ('Nike Huarache Type', 8, 842),
#  ('Nike Zoom 2K', 8, 842),
#  ("MEN'S ADIDAS OUTDOOR BEARN SHOES", 8, 842),
#  ("MEN'S ADIDAS SPORT INSPIRED VS PACE SHOES", 8, 842),
#  ("Women's adidas fluidcloud Low Shoes", 8, 842),
#  ("Men's adidas Originals Rivalry RM Shoes", 8, 842),
#  ("Men's adidas Swim Eezay Maxout II Slippers", 8, 842),
#  ("Men's adidas Football Copa 20.4 Firm Ground Boots", 8, 842),
#  ("Men's adidas Running AlphaBoost BF Shoes", 8, 842),
#  ('NAHA', 7, 942),
#  ('Nike Air Zoom Pegasus 36 FlyEase', 7, 942),
#  ("WOMEN'S ADIDAS SPORT INSPIRED ULTIMAMOTION SHOES", 7, 942),
#  ("WoMen's adidas TRAINING CRAZYMOVE TR SHOES", 7, 942),
#  ('Nike Mercurial Superfly 7 Elite MDS FG', 7, 942),
#  ('Nike Zoom Vomero 5 SE SP', 7, 942),
#  ("Men's Football Predator 20.3 LL Turf Boots", 7, 942),
#  ("Men's adidas Originals Crazy BYW BF Shoes", 7, 942),
#  ("Men's Football Nemeziz 19.3 Indoor Shoes", 7, 942),
#  ("Women's adidas Sport Inspired Storm Runner Shoes", 7, 942),
#  ("Men's adidas Training FitBounce Trainers", 7, 942),
#  ("Men's Originals Stan Smith Shoes", 7, 942),
#  ("Men's Outdoor Elevate Sandals", 7, 942),
#  ("Women's adidas Running Solar Boost 19 Shoes", 7, 942),
#  ("Women's adidas Originals Superstar Metal Toe Shoes", 7, 942),
#  ("Men's adidas Running Adi Pacer 4.0 Shoes", 7, 942),
#  ("WOMEN'S ADIDAS RUNNING PUREBOUNCE+ STREET SHOES", 7, 942),
#  ('Kyrie Low 2', 7, 942),
#  ("Men's adidas Adilette Comfort Adjustable Slides", 7, 942),
#  ('Nike React Presto Premium', 7, 942),
#  ('Nike AF-1 Shadow SE', 7, 942),
#  ("Women's Originals Superstar Bold Shoes", 7, 942),
#  ("Women's Sport Inspired Grand Court Shoes", 7, 942),
#  ("WOMEN's adidas ORIGINALS TUBULAR DAWN SHOES", 7, 942),
#  ("Men's Originals Stan Smith Human Made Shoes", 7, 942),
#  ("Men's adidas Sport Inspired Hoops 2.0 Shoes", 7, 942),
#  ('Nike x Carhartt WIP Air Max 95', 7, 942),
#  ("Men's adidas Running Pureboost RBL Shoes", 7, 942),
#  ('Nike Air Force 1 Sage Low', 7, 942),
#  ("men's ADIDAS RUNNING HELKIN 3 SHOES", 7, 942),
#  ('Air Jordan 1 Mid SE', 7, 942),
#  ('Nike P-6000 Icon Clash', 7, 942),
#  ("Men's adidas Originals Seeley Shoes", 7, 942),
#  ("Women's Running Duramo 9 Shoes", 7, 942),
#  ("Men's adidas Football Nemeziz 19.3 Turf Boots", 7, 942),
#  ("Men's Running Dectron Shoes", 7, 942),
#  ('Unisex adidas ORIGINALS KIEL SHOES', 7, 942),
#  ('Nike iSPA React', 7, 942),
#  ('Unisex Adidas ORIGINALS SKATEBOARDING ADI-EASE VULCANIZED SHOES', 7, 942),
#  ('Nike Air Max 90 QS', 7, 942),
#  ('Kids-Unisex Running RapidaRun Knit EL Shoes', 7, 942),
#  ("WOMEN'S ADIDAS ORIGINALS FLB_RUNNER SHOES", 7, 942),
#  ("Men's adidas Outdoor Volantis II Shoes", 7, 942),
#  ('Nike React Metcon AMP', 7, 942),
#  ("Men's adidas Football Predator 19.1 Trainers", 7, 942),
#  ('Nike Pegasus 36 FlyEase (Extra Wide)', 7, 942),
#  ('Unisex adidas Running Adizero RC Shoes', 7, 942),
#  ("Men's Football Predator 20.4 Flexible Ground Shoes", 7, 942),
#  ("WOMEN'S ADIDAS OUTDOOR ELEVATE SANDALS", 7, 942),
#  ("MEN'S ADIDAS SPORT INSPIRED FUSION FLOW SHOES", 7, 942),
#  ("Men's adidas Originals 424 Pro Model Shoes", 7, 942),
#  ('Nike Zoom Rival Fly 2', 7, 942),
#  ('Nike SB Dunk High Pro', 7, 942),
#  ('Nike x MMW Joyride CC3 Setter', 7, 942),
#  ("MEN'S ADIDAS FOOTBALL NEMEZIZ MESSI 18.4 FLEXIBLE GROUND BOOTS", 7, 942),
#  ("WOMEN'S ADIDAS SPORT INSPIRED ENERGY CLOUD V SHOES", 7, 942),
#  ('Nike Air Max 270 SE', 7, 942),
#  ("Men's Basketball Gametalker Shoes", 7, 942),
#  ("Men's Originals Crazy BYW X 2.0 Shoes", 7, 942),
#  ...]
